# %%
# !uv pip install pandas
# Out:
# Resolved 6 packages in 261ms
# Prepared 3 packages in 1.17s
# Installed 3 packages in 75ms
#  + numpy==2.3.5
#  + pandas==2.3.3
#  + pytz==2025.2

# %%
import requests
from pprint import pprint
import os
import pandas as pd



APP_ID = os.environ.get("TFL_APP_ID")
APP_KEY = os.environ.get("TFL_APP_KEY")
base_url = "https://api.tfl.gov.uk"


def fetch_tfl_data(endpoint, params=None):
    url = f"{base_url}{endpoint}"
    params = params or {}
    params.update({"app_id": APP_ID, "app_key": APP_KEY})

    try:
        response = requests.get(url, params=params, timeout=15)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.HTTPError as e:
        print(f"\nHTTP Error {response.status_code}: {response.text}")
        return None
    except Exception as e:
        print(f"\nError fetching {url}: {str(e)}")
        return None

# %% [markdown]
# # Constructing the TFL network as a Graph
# ### Steps
# 1. Decide on the list of transport modes you want and ensure they are supported
# 2. For each mode, get the list of lines (e.g. tube, victoria)
# 3. For each line, get the ordered list of stations that serve that line, name + id
# 4. For each station+line, construct a node_id and save these nodes
# 5. From the ordered list of stations, construct a set of same line edges, one station apart
# 6. For each station, append the lines it serves, and construct interstation edges
# 7. For the interline edges, query tfl for the times to get from each station to the next
# 8. For the interstation egdes, identify a method for determining the transition time (one idea, try a query for one station before and one after on each side, and subtract the known train times to that station.
# 9. Construct the graph with our nodes and edges
# 10. Run Dijkstra and get all node->node times
# 11. Collapse routes with multipe platforms to the minimum distance.
# 12. YUUU$$$

# %%
all_modes = fetch_tfl_data("/Line/Meta/Modes")
for mode in all_modes:
    print(mode["modeName"])
# Out:
# bus
# cable-car
# coach
# cycle
# cycle-hire
# dlr
# elizabeth-line
# interchange-keep-sitting
# interchange-secure
# national-rail
# overground
# replacement-bus
# river-bus
# river-tour
# taxi
# tram
# tube
# walking

# %%
modes = ["tube", "overground", "dlr", "elizabeth-line", "tram"]
lines = fetch_tfl_data("/Line/Mode/" + ",".join(modes))

# %%
line_ids = []
lines_ld = []
for line in lines:
    #print(line["id"], line["name"], line["modeName"])
    line_ids.append(line["id"])
    line_d = {}
    line_d["line_name"] = line["name"]
    line_d["line_id"] = line["id"]
    lines_ld.append(line_d)

df = pd.DataFrame(lines_ld)
print(df)
# Out:
#              line_name           line_id
# 0             Bakerloo          bakerloo
# 1              Central           central
# 2               Circle            circle
# 3             District          district
# 4                  DLR               dlr
# 5       Elizabeth line         elizabeth
# 6   Hammersmith & City  hammersmith-city
# 7              Jubilee           jubilee
# 8              Liberty           liberty
# 9              Lioness           lioness
# 10        Metropolitan      metropolitan
# 11             Mildmay           mildmay
# 12            Northern          northern
# 13          Piccadilly        piccadilly
# 14         Suffragette       suffragette
# 15                Tram              tram
# 16            Victoria          victoria
# 17     Waterloo & City     waterloo-city
# 18              Weaver            weaver
# 19            Windrush          windrush

# %%
id = "HUBEPH"
stops = fetch_tfl_data(f"/StopPoint/940GZZLUBST,{id},940GZZLULGT")
pprint(stops, depth=2)
#pprint(stops["children"], depth=2)
#for x in stops["children"]:
#    print(x["commonName"], x["naptanId"], x["stationNaptan"])
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPoint, '
#            'Tfl.Api.Presentation.Entities',
#   'additionalProperties': [...],
#   'children': [...],
#   'commonName': 'Baker Street Underground Station',
#   'icsCode': '1000011',
#   'id': '940GZZLUBST',
#   'lat': 51.522883,
#   'lineGroup': [...],
#   'lineModeGroups': [...],
#   'lines': [...],
#   'lon': -0.15713,
#   'modes': [...],
#   'naptanId': '940GZZLUBST',
#   'placeType': 'StopPoint',
#   'stationNaptan': '940GZZLUBST',
#   'status': True,
#   'stopType': 'NaptanMetroStation'},
#  {'$type': 'Tfl.Api.Presentation.Entities.StopPoint, '
#            'Tfl.Api.Presentation.Entities',
#   'additionalProperties': [...],
#   'children': [...],
#   'commonName': 'Lancaster Gate Underground Station',
#   'icsCode': '1000133',
#   'id': '940GZZLULGT',
#   'lat': 51.511723,
#   'lineGroup': [...],
#   'lineModeGroups': [...],
#   'lines': [...],
#   'lon': -0.175494,
#   'modes': [...],
#   'naptanId': '940GZZLULGT',
#   'placeType': 'StopPoint',
#   'stationNaptan': '940GZZLULGT',
#   'status': True,
#   'stopType': 'NaptanMetroStation'},
#  {'$type': 'Tfl.Api.Presentation.Entities.StopPoint, '
#            'Tfl.Api.Presentation.Entities',
#   'additionalProperties': [...],
#   'children': [...],
#   'commonName': 'Elephant & Castle',
#   'hubNaptanCode': 'HUBEPH',
#   'icsCode': '1000073',
#   'id': 'HUBEPH',
#   'lat': 51.494505,
#   'lineGroup': [...],
#   'lineModeGroups': [...],
#   'lines': [...],
#   'lon': -0.099185,
#   'modes': [...],
#   'naptanId': 'HUBEPH',
#   'placeType': 'StopPoint',
#   'status': True,
#   'stopType': 'TransportInterchange'}]

# %%
station_id = {}
station_dict = []
hubs = []
strs = []

for line_id in line_ids:
    stops = fetch_tfl_data(f"/Line/{line_id}/StopPoints?tflOperatedNationalRailStationsOnly=false")
    #print(stops[0].keys())
    #pprint(stops, depth=2, compact=True)
    #print("\n\n")
    #pprint(stops[0]["children"])
    for stop in stops:
        name = stop["commonName"]
        naptanId = stop["stationNaptan"]
        lat = stop["lat"]
        lon = stop["lon"]
        hub_name = name
        if hub := stop.get("hubNaptanCode", None):
            hubs.append(hub)
            hub_name = None
        print(line_id, name, naptanId, hub, hub_name, lat, lon)

        
        #pprint(stop, depth=2)
        #for x in stop["children"]:
        #    print(line_id, x["commonName"], x["naptanId"], x["stationNaptan"], hub)

        #print(f"{naptanId}: {name} - {line_id} - {hub}")
        strs.append(f"{name} - {naptanId} - {line_id} = {hub}")
        station_id[naptanId] = name
        station = {}
        station["station_id"] = naptanId
        station["station_name"] = name
        station["station_line"] = line_id
        station_dict.append(station)
df = pd.DataFrame(station_dict)
strs = sorted(strs)
for s in strs:
    print(s)
#print(hubs)
#df.head()
# Out:
# bakerloo Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station 51.522883 -0.15713
# bakerloo Charing Cross Underground Station 940GZZLUCHX HUBCHX None 51.50741 -0.127277
# bakerloo Elephant & Castle Underground Station 940GZZLUEAC HUBEPH None 51.494536 -0.100606
# bakerloo Embankment Underground Station 940GZZLUEMB None Embankment Underground Station 51.507058 -0.122666
# bakerloo Edgware Road (Bakerloo) Underground Station 940GZZLUERB None Edgware Road (Bakerloo) Underground Station 51.520299 -0.17015
# bakerloo Harrow & Wealdstone Underground Station 940GZZLUHAW HUBHRW None 51.592268 -0.335217
# bakerloo Harlesden Underground Station 940GZZLUHSN HUBHDN None 51.53631 -0.257883
# bakerloo Kenton Underground Station 940GZZLUKEN HUBKNT None 51.581756 -0.31691
# bakerloo Kilburn Park Underground Station 940GZZLUKPK None Kilburn Park Underground Station 51.534979 -0.194232
# bakerloo Kensal Green Underground Station 940GZZLUKSL HUBKNL None 51.530539 -0.225016
# bakerloo Lambeth North Underground Station 940GZZLULBN None Lambeth North Underground Station 51.498808 -0.112315
# bakerloo Maida Vale Underground Station 940GZZLUMVL None Maida Vale Underground Station 51.529777 -0.185758
# bakerloo Marylebone Underground Station 940GZZLUMYB HUBMYB None 51.522322 -0.163207
# bakerloo North Wembley Underground Station 940GZZLUNWY HUBNWB None 51.562551 -0.304
# bakerloo Oxford Circus Underground Station 940GZZLUOXC None Oxford Circus Underground Station 51.515224 -0.141903
# bakerloo Paddington Underground Station 940GZZLUPAC HUBPAD None 51.516581 -0.175689
# bakerloo Piccadilly Circus Underground Station 940GZZLUPCC None Piccadilly Circus Underground Station 51.51005 -0.133798
# bakerloo Queen's Park Underground Station 940GZZLUQPS HUBQPW None 51.534158 -0.204574
# bakerloo Regent's Park Underground Station 940GZZLURGP None Regent's Park Underground Station 51.523344 -0.146444
# bakerloo Stonebridge Park Underground Station 940GZZLUSGP HUBSBP None 51.543959 -0.275892
# bakerloo South Kenton Underground Station 940GZZLUSKT HUBSOK None 51.570232 -0.308433
# bakerloo Willesden Junction Underground Station 940GZZLUWJN HUBWIJ None 51.532259 -0.244283
# bakerloo Warwick Avenue Underground Station 940GZZLUWKA None Warwick Avenue Underground Station 51.523263 -0.183783
# bakerloo Waterloo Underground Station 940GZZLUWLO HUBWAT None 51.503299 -0.11478
# bakerloo Wembley Central Underground Station 940GZZLUWYC HUBWMB None 51.552304 -0.296852
# central Barkingside Underground Station 940GZZLUBKE None Barkingside Underground Station 51.585689 0.088585
# central Buckhurst Hill Underground Station 940GZZLUBKH None Buckhurst Hill Underground Station 51.626605 0.046757
# central Bethnal Green Underground Station 940GZZLUBLG None Bethnal Green Underground Station 51.527222 -0.055506
# central Bond Street Underground Station 940GZZLUBND HUBBDS None 51.514304 -0.149723
# central Bank Underground Station 940GZZLUBNK HUBBAN None 51.513132 -0.090047
# central Chancery Lane Underground Station 940GZZLUCHL None Chancery Lane Underground Station 51.518247 -0.111583
# central Chigwell Underground Station 940GZZLUCWL None Chigwell Underground Station 51.617916 0.075041
# central Debden Underground Station 940GZZLUDBN None Debden Underground Station 51.645386 0.083782
# central East Acton Underground Station 940GZZLUEAN None East Acton Underground Station 51.516612 -0.247248
# central Ealing Broadway Underground Station 940GZZLUEBY HUBEAL None 51.515017 -0.301457
# central Epping Underground Station 940GZZLUEPG None Epping Underground Station 51.69368 0.113767
# central Fairlop Underground Station 940GZZLUFLP None Fairlop Underground Station 51.595618 0.091004
# central Greenford Underground Station 940GZZLUGFD HUBGFD None 51.542424 -0.34605
# central Grange Hill Underground Station 940GZZLUGGH None Grange Hill Underground Station 51.613378 0.092066
# central Gants Hill Underground Station 940GZZLUGTH None Gants Hill Underground Station 51.576544 0.066185
# central Holborn Underground Station 940GZZLUHBN None Holborn Underground Station 51.51758 -0.120475
# central Hanger Lane Underground Station 940GZZLUHGR None Hanger Lane Underground Station 51.530177 -0.292704
# central Hainault Underground Station 940GZZLUHLT None Hainault Underground Station 51.603659 0.093482
# central Holland Park Underground Station 940GZZLUHPK None Holland Park Underground Station 51.507143 -0.205679
# central Loughton Underground Station 940GZZLULGN None Loughton Underground Station 51.641443 0.055476
# central Lancaster Gate Underground Station 940GZZLULGT None Lancaster Gate Underground Station 51.511723 -0.175494
# central Liverpool Street Underground Station 940GZZLULVT HUBLST None 51.517372 -0.083182
# central Leyton Underground Station 940GZZLULYN None Leyton Underground Station 51.556589 -0.005523
# central Leytonstone Underground Station 940GZZLULYS None Leytonstone Underground Station 51.568324 0.008194
# central Marble Arch Underground Station 940GZZLUMBA None Marble Arch Underground Station 51.513424 -0.158953
# central Mile End Underground Station 940GZZLUMED None Mile End Underground Station 51.525122 -0.03364
# central North Acton Underground Station 940GZZLUNAN None North Acton Underground Station 51.523524 -0.259755
# central Newbury Park Underground Station 940GZZLUNBP None Newbury Park Underground Station 51.575726 0.090004
# central Notting Hill Gate Underground Station 940GZZLUNHG None Notting Hill Gate Underground Station 51.509128 -0.196104
# central Northolt Underground Station 940GZZLUNHT None Northolt Underground Station 51.548236 -0.368699
# central Oxford Circus Underground Station 940GZZLUOXC None Oxford Circus Underground Station 51.515224 -0.141903
# central Perivale Underground Station 940GZZLUPVL None Perivale Underground Station 51.536717 -0.323446
# central Queensway Underground Station 940GZZLUQWY None Queensway Underground Station 51.510312 -0.187152
# central Redbridge Underground Station 940GZZLURBG None Redbridge Underground Station 51.576243 0.04536
# central Ruislip Gardens Underground Station 940GZZLURSG None Ruislip Gardens Underground Station 51.560736 -0.41071
# central Roding Valley Underground Station 940GZZLURVY None Roding Valley Underground Station 51.617199 0.043647
# central Shepherd's Bush (Central) Underground Station 940GZZLUSBC HUBSPB None 51.504376 -0.218813
# central Snaresbrook Underground Station 940GZZLUSNB None Snaresbrook Underground Station 51.580678 0.02144
# central St. Paul's Underground Station 940GZZLUSPU None St. Paul's Underground Station 51.514936 -0.097567
# central South Ruislip Underground Station 940GZZLUSRP HUBSRU None 51.556853 -0.398915
# central Stratford Underground Station 940GZZLUSTD HUBSRA None 51.541806 -0.003458
# central South Woodford Underground Station 940GZZLUSWF None South Woodford Underground Station 51.591907 0.027338
# central Tottenham Court Road Underground Station 940GZZLUTCR HUBTCR None 51.516426 -0.13041
# central Theydon Bois Underground Station 940GZZLUTHB None Theydon Bois Underground Station 51.671759 0.103085
# central White City Underground Station 940GZZLUWCY None White City Underground Station 51.511959 -0.224297
# central Woodford Underground Station 940GZZLUWOF None Woodford Underground Station 51.606899 0.03397
# central West Ruislip Underground Station 940GZZLUWRP HUBWRU None 51.569688 -0.437886
# central Wanstead Underground Station 940GZZLUWSD None Wanstead Underground Station 51.575501 0.028527
# central West Acton Underground Station 940GZZLUWTA None West Acton Underground Station 51.518001 -0.28098
# circle Aldgate Underground Station 940GZZLUALD None Aldgate Underground Station 51.514246 -0.075689
# circle Barbican Underground Station 940GZZLUBBN None Barbican Underground Station 51.520275 -0.097993
# circle Blackfriars Underground Station 940GZZLUBKF HUBBFR None 51.511581 -0.103659
# circle Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station 51.522883 -0.15713
# circle Bayswater Underground Station 940GZZLUBWT None Bayswater Underground Station 51.512284 -0.187938
# circle Cannon Street Underground Station 940GZZLUCST HUBCST None 51.51151 -0.090432
# circle Embankment Underground Station 940GZZLUEMB None Embankment Underground Station 51.507058 -0.122666
# circle Edgware Road (Circle Line) Underground Station 940GZZLUERC None Edgware Road (Circle Line) Underground Station 51.519858 -0.167832
# circle Euston Square Underground Station 940GZZLUESQ None Euston Square Underground Station 51.525604 -0.135829
# circle Farringdon Underground Station 940GZZLUFCN HUBZFD None 51.520252 -0.104913
# circle Goldhawk Road Underground Station 940GZZLUGHK None Goldhawk Road Underground Station 51.502005 -0.226715
# circle Great Portland Street Underground Station 940GZZLUGPS None Great Portland Street Underground Station 51.52384 -0.144262
# circle Gloucester Road Underground Station 940GZZLUGTR None Gloucester Road Underground Station 51.494316 -0.182658
# circle Hammersmith (H&C Line) Underground Station 940GZZLUHSC HUBHMS None 51.49339 -0.22503
# circle High Street Kensington Underground Station 940GZZLUHSK None High Street Kensington Underground Station 51.501055 -0.192792
# circle King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None 51.530663 -0.123194
# circle Ladbroke Grove Underground Station 940GZZLULAD None Ladbroke Grove Underground Station 51.517449 -0.210391
# circle Latimer Road Underground Station 940GZZLULRD None Latimer Road Underground Station 51.513389 -0.217799
# circle Liverpool Street Underground Station 940GZZLULVT HUBLST None 51.517372 -0.083182
# circle Moorgate Underground Station 940GZZLUMGT HUBZMG None 51.518176 -0.088322
# circle Monument Underground Station 940GZZLUMMT None Monument Underground Station 51.5107 -0.085969
# circle Mansion House Underground Station 940GZZLUMSH None Mansion House Underground Station 51.512117 -0.094009
# circle Notting Hill Gate Underground Station 940GZZLUNHG None Notting Hill Gate Underground Station 51.509128 -0.196104
# circle Paddington Underground Station 940GZZLUPAC HUBPAD None 51.516581 -0.175689
# circle Paddington (H&C Line)-Underground 940GZZLUPAH HUBPAD None 51.518187 -0.178306
# circle Royal Oak Underground Station 940GZZLURYO None Royal Oak Underground Station 51.519113 -0.188748
# circle Shepherd's Bush Market Underground Station 940GZZLUSBM None Shepherd's Bush Market Underground Station 51.505579 -0.226375
# circle St. James's Park Underground Station 940GZZLUSJP None St. James's Park Underground Station 51.499544 -0.133608
# circle South Kensington Underground Station 940GZZLUSKS None South Kensington Underground Station 51.494094 -0.174138
# circle Sloane Square Underground Station 940GZZLUSSQ None Sloane Square Underground Station 51.49227 -0.156377
# circle Temple Underground Station 940GZZLUTMP None Temple Underground Station 51.511006 -0.11426
# circle Tower Hill Underground Station 940GZZLUTWH None Tower Hill Underground Station 51.509971 -0.076546
# circle Victoria Underground Station 940GZZLUVIC HUBVIC None 51.496359 -0.143102
# circle Wood Lane Underground Station 940GZZLUWLA None Wood Lane Underground Station 51.509669 -0.22453
# circle Westminster Underground Station 940GZZLUWSM HUBWSM None 51.50132 -0.124861
# circle Westbourne Park Underground Station 940GZZLUWSP None Westbourne Park Underground Station 51.52111 -0.201065
# district Acton Town Underground Station 940GZZLUACT None Acton Town Underground Station 51.503057 -0.280462
# district Aldgate East Underground Station 940GZZLUADE None Aldgate East Underground Station 51.515037 -0.072384
# district Bromley-by-Bow Underground Station 940GZZLUBBB None Bromley-by-Bow Underground Station 51.524839 -0.011538
# district Becontree Underground Station 940GZZLUBEC None Becontree Underground Station 51.540331 0.127016
# district Blackfriars Underground Station 940GZZLUBKF HUBBFR None 51.511581 -0.103659
# district Barking Underground Station 940GZZLUBKG HUBBKG None 51.539321 0.081053
# district Barons Court Underground Station 940GZZLUBSC None Barons Court Underground Station 51.490311 -0.213427
# district Bow Road Underground Station 940GZZLUBWR None Bow Road Underground Station 51.52694 -0.025128
# district Bayswater Underground Station 940GZZLUBWT None Bayswater Underground Station 51.512284 -0.187938
# district Cannon Street Underground Station 940GZZLUCST HUBCST None 51.51151 -0.090432
# district Chiswick Park Underground Station 940GZZLUCWP None Chiswick Park Underground Station 51.494627 -0.267972
# district Dagenham East Underground Station 940GZZLUDGE None Dagenham East Underground Station 51.544096 0.166017
# district Dagenham Heathway Underground Station 940GZZLUDGY None Dagenham Heathway Underground Station 51.541639 0.147527
# district Ealing Broadway Underground Station 940GZZLUEBY HUBEAL None 51.515017 -0.301457
# district Ealing Common Underground Station 940GZZLUECM None Ealing Common Underground Station 51.51014 -0.288265
# district Earl's Court Underground Station 940GZZLUECT None Earl's Court Underground Station 51.492063 -0.193378
# district East Ham Underground Station 940GZZLUEHM None East Ham Underground Station 51.538948 0.051186
# district Embankment Underground Station 940GZZLUEMB None Embankment Underground Station 51.507058 -0.122666
# district Elm Park Underground Station 940GZZLUEPK None Elm Park Underground Station 51.549775 0.19864
# district East Putney Underground Station 940GZZLUEPY None East Putney Underground Station 51.459205 -0.211
# district Edgware Road (Circle Line) Underground Station 940GZZLUERC None Edgware Road (Circle Line) Underground Station 51.519858 -0.167832
# district Fulham Broadway Underground Station 940GZZLUFBY None Fulham Broadway Underground Station 51.480081 -0.195422
# district Gunnersbury Underground Station 940GZZLUGBY HUBGUN None 51.491803 -0.275267
# district Gloucester Road Underground Station 940GZZLUGTR None Gloucester Road Underground Station 51.494316 -0.182658
# district Hornchurch Underground Station 940GZZLUHCH None Hornchurch Underground Station 51.554093 0.219116
# district Hammersmith (Dist&Picc Line) Underground Station 940GZZLUHSD HUBHMS None 51.4923 -0.22362
# district High Street Kensington Underground Station 940GZZLUHSK None High Street Kensington Underground Station 51.501055 -0.192792
# district Kensington (Olympia) Underground Station 940GZZLUKOY HUBKPA None 51.497624 -0.210015
# district Kew Gardens Underground Station 940GZZLUKWG HUBKWG None 51.477058 -0.285241
# district Mile End Underground Station 940GZZLUMED None Mile End Underground Station 51.525122 -0.03364
# district Monument Underground Station 940GZZLUMMT None Monument Underground Station 51.5107 -0.085969
# district Mansion House Underground Station 940GZZLUMSH None Mansion House Underground Station 51.512117 -0.094009
# district Notting Hill Gate Underground Station 940GZZLUNHG None Notting Hill Gate Underground Station 51.509128 -0.196104
# district Paddington Underground Station 940GZZLUPAC HUBPAD None 51.516581 -0.175689
# district Plaistow Underground Station 940GZZLUPLW None Plaistow Underground Station 51.531341 0.017451
# district Parsons Green Underground Station 940GZZLUPSG None Parsons Green Underground Station 51.475277 -0.20117
# district Putney Bridge Underground Station 940GZZLUPYB None Putney Bridge Underground Station 51.468262 -0.208731
# district Richmond Underground Station 940GZZLURMD HUBRMD None 51.463237 -0.301336
# district Ravenscourt Park Underground Station 940GZZLURVP None Ravenscourt Park Underground Station 51.494122 -0.235881
# district Stamford Brook Underground Station 940GZZLUSFB None Stamford Brook Underground Station 51.494917 -0.245704
# district Southfields Underground Station 940GZZLUSFS None Southfields Underground Station 51.445073 -0.206602
# district Stepney Green Underground Station 940GZZLUSGN None Stepney Green Underground Station 51.521858 -0.046596
# district St. James's Park Underground Station 940GZZLUSJP None St. James's Park Underground Station 51.499544 -0.133608
# district South Kensington Underground Station 940GZZLUSKS None South Kensington Underground Station 51.494094 -0.174138
# district Sloane Square Underground Station 940GZZLUSSQ None Sloane Square Underground Station 51.49227 -0.156377
# district Temple Underground Station 940GZZLUTMP None Temple Underground Station 51.511006 -0.11426
# district Turnham Green Underground Station 940GZZLUTNG None Turnham Green Underground Station 51.495148 -0.254555
# district Tower Hill Underground Station 940GZZLUTWH None Tower Hill Underground Station 51.509971 -0.076546
# district Upminster Bridge Underground Station 940GZZLUUPB None Upminster Bridge Underground Station 51.55856 0.235809
# district Upton Park Underground Station 940GZZLUUPK None Upton Park Underground Station 51.53534 0.035263
# district Upminster Underground Station 940GZZLUUPM HUBUPM None 51.559063 0.250882
# district Upney Underground Station 940GZZLUUPY None Upney Underground Station 51.538372 0.10153
# district Victoria Underground Station 940GZZLUVIC HUBVIC None 51.496359 -0.143102
# district West Brompton Underground Station 940GZZLUWBN HUBWBP None 51.487268 -0.195599
# district West Ham Underground Station 940GZZLUWHM HUBWEH None 51.528136 0.005055
# district Wimbledon Underground Station 940GZZLUWIM HUBWIM None 51.421207 -0.206573
# district Wimbledon Park Underground Station 940GZZLUWIP None Wimbledon Park Underground Station 51.434573 -0.199719
# district West Kensington Underground Station 940GZZLUWKN None West Kensington Underground Station 51.490459 -0.206636
# district Whitechapel Underground Station 940GZZLUWPL HUBZWL None 51.519518 -0.059971
# district Westminster Underground Station 940GZZLUWSM HUBWSM None 51.50132 -0.124861
# dlr Abbey Road DLR Station 940GZZDLABR None Abbey Road DLR Station 51.531926 0.003737
# dlr All Saints DLR Station 940GZZDLALL None All Saints DLR Station 51.511 -0.013135
# dlr Beckton DLR Station 940GZZDLBEC None Beckton DLR Station 51.514362 0.061453
# dlr Blackwall DLR Station 940GZZDLBLA None Blackwall DLR Station 51.507991 -0.006969
# dlr Bank DLR Station 940GZZDLBNK HUBBAN None 51.513233 -0.088515
# dlr Bow Church DLR Station 940GZZDLBOW None Bow Church DLR Station 51.527858 -0.020936
# dlr Beckton Park DLR Station 940GZZDLBPK None Beckton Park DLR Station 51.508793 0.054932
# dlr Canary Wharf DLR Station 940GZZDLCAN HUBCAW None 51.504838 -0.020997
# dlr Canning Town DLR Station 940GZZDLCGT HUBCAN None 51.514127 0.008101
# dlr Crossharbour DLR Station 940GZZDLCLA None Crossharbour DLR Station 51.495728 -0.014606
# dlr Custom House (for ExCel) DLR Station 940GZZDLCUS HUBCUS None 51.509716 0.026699
# dlr Cutty Sark (for Maritime Greenwich) DLR Station 940GZZDLCUT HUBCUT None 51.481671 -0.01081
# dlr Cyprus DLR Station 940GZZDLCYP None Cyprus DLR Station 51.508473 0.063925
# dlr Deptford Bridge DLR Station 940GZZDLDEP None Deptford Bridge DLR Station 51.474215 -0.022438
# dlr Devons Road DLR Station 940GZZDLDEV None Devons Road DLR Station 51.522667 -0.017615
# dlr East India DLR Station 940GZZDLEIN None East India DLR Station 51.509359 -0.002326
# dlr Elverson Road DLR Station 940GZZDLELV None Elverson Road DLR Station 51.469074 -0.016728
# dlr Gallions Reach DLR Station 940GZZDLGAL None Gallions Reach DLR Station 51.508941 0.071555
# dlr Greenwich DLR Station 940GZZDLGRE HUBGNW None 51.478087 -0.013673
# dlr Heron Quays DLR Station 940GZZDLHEQ None Heron Quays DLR Station 51.503379 -0.021421
# dlr Island Gardens DLR Station 940GZZDLISL None Island Gardens DLR Station 51.487811 -0.010139
# dlr King George V DLR Station 940GZZDLKGV None King George V DLR Station 51.502003 0.062624
# dlr London City Airport DLR Station 940GZZDLLCA HUBLCY None 51.503416 0.048739
# dlr Langdon Park DLR Station 940GZZDLLDP None Langdon Park DLR Station 51.515172 -0.01415
# dlr Lewisham DLR Station 940GZZDLLEW HUBLEW None 51.464665 -0.012874
# dlr Limehouse DLR Station 940GZZDLLIM HUBLHS None 51.512393 -0.039809
# dlr Mudchute DLR Station 940GZZDLMUD None Mudchute DLR Station 51.490704 -0.014738
# dlr Pontoon Dock DLR Station 940GZZDLPDK None Pontoon Dock DLR Station 51.502212 0.032115
# dlr Poplar DLR Station 940GZZDLPOP None Poplar DLR Station 51.507744 -0.017384
# dlr Prince Regent DLR Station 940GZZDLPRE None Prince Regent DLR Station 51.509263 0.034158
# dlr Pudding Mill Lane DLR Station 940GZZDLPUD None Pudding Mill Lane DLR Station 51.534302 -0.012755
# dlr Royal Albert DLR Station 940GZZDLRAL None Royal Albert DLR Station 51.508357 0.045935
# dlr Royal Victoria DLR Station 940GZZDLRVC HUBRVC None 51.509336 0.018497
# dlr Shadwell DLR Station 940GZZDLSHA HUBSDE None 51.511693 -0.056643
# dlr Stratford High Street DLR Station 940GZZDLSHS None Stratford High Street DLR Station 51.538196 -0.001078
# dlr Stratford International DLR Station 940GZZDLSIT None Stratford International DLR Station 51.545265 -0.009638
# dlr South Quay DLR Station 940GZZDLSOQ None South Quay DLR Station 51.50005 -0.01597
# dlr Stratford DLR Station 940GZZDLSTD HUBSRA None 51.541758 -0.003287
# dlr Star Lane DLR Station 940GZZDLSTL None Star Lane DLR Station 51.520786 0.004156
# dlr Tower Gateway DLR Station 940GZZDLTWG HUBTOG None 51.510617 -0.074818
# dlr Westferry DLR Station 940GZZDLWFE None Westferry DLR Station 51.509431 -0.02675
# dlr West Ham DLR Station 940GZZDLWHM HUBWEH None 51.527894 0.004482
# dlr West India Quay DLR Station 940GZZDLWIQ None West India Quay DLR Station 51.50703 -0.020311
# dlr Woolwich Arsenal DLR Station 940GZZDLWLA HUBWWA None 51.490009 0.069127
# dlr West Silvertown DLR Station 940GZZDLWSV None West Silvertown DLR Station 51.502838 0.02246
# elizabeth Abbey Wood 910GABWDXR HUBABW None 51.491241 0.121374
# elizabeth Acton Main Line Rail Station 910GACTONML None Acton Main Line Rail Station 51.51718 -0.266756
# elizabeth Burnham (Berks) Rail Station 910GBNHAM None Burnham (Berks) Rail Station 51.523506 -0.646374
# elizabeth Bond Street 910GBONDST HUBBDS None 51.51369 -0.149517
# elizabeth Brentwood Rail Station 910GBRTWOOD None Brentwood Rail Station 51.613605 0.299586
# elizabeth Canary Wharf 910GCANWHRF HUBCAW None 51.506321 -0.018815
# elizabeth Chadwell Heath Rail Station 910GCHDWLHT None Chadwell Heath Rail Station 51.568039 0.128958
# elizabeth Custom House Rail Station 910GCUSTMHS HUBCUS None 51.509835 0.02656
# elizabeth Ealing Broadway Rail Station 910GEALINGB HUBEAL None 51.514841 -0.301752
# elizabeth Farringdon 910GFRNDXR HUBZFD None 51.519961 -0.103051
# elizabeth Forest Gate Rail Station 910GFRSTGT None Forest Gate Rail Station 51.549432 0.024353
# elizabeth Gidea Park Rail Station 910GGIDEAPK None Gidea Park Rail Station 51.581904 0.205964
# elizabeth Goodmayes Rail Station 910GGODMAYS None Goodmayes Rail Station 51.565579 0.110807
# elizabeth Hanwell Rail Station 910GHANWELL None Hanwell Rail Station 51.511835 -0.338583
# elizabeth Hayes & Harlington Rail Station 910GHAYESAH None Hayes & Harlington Rail Station 51.503096 -0.420683
# elizabeth Harold Wood Rail Station 910GHRLDWOD None Harold Wood Rail Station 51.592766 0.233129
# elizabeth Heathrow Terminals 2 & 3 Rail Station 910GHTRWAPT HUBH13 None 51.471987 -0.454788
# elizabeth Heathrow Terminal 4 Rail Station 910GHTRWTM4 HUBHX4 None 51.458268 -0.445463
# elizabeth Heathrow Terminal 5 Rail Station 910GHTRWTM5 HUBHX5 None 51.470053 -0.490589
# elizabeth Ilford Rail Station 910GILFORD None Ilford Rail Station 51.559118 0.06968
# elizabeth Iver Rail Station 910GIVER None Iver Rail Station 51.508503 -0.506726
# elizabeth Langley (Berks) Rail Station 910GLANGLEY None Langley (Berks) Rail Station 51.508062 -0.541756
# elizabeth London Liverpool Street Rail Station 910GLIVST HUBLST None 51.517991 -0.081426
# elizabeth Liverpool Street 910GLIVSTLL HUBLST None 51.517721 -0.082043
# elizabeth Manor Park Rail Station 910GMANRPK None Manor Park Rail Station 51.552477 0.046342
# elizabeth Maidenhead Rail Station 910GMDNHEAD None Maidenhead Rail Station 51.518669 -0.72266
# elizabeth Maryland Rail Station 910GMRYLAND None Maryland Rail Station 51.546081 0.005815
# elizabeth Paddington 910GPADTLL HUBPAD None 51.516449 -0.177107
# elizabeth London Paddington Rail Station 910GPADTON HUBPAD None 51.515996 -0.176174
# elizabeth Reading Rail Station 910GRDNGSTN None Reading Rail Station 51.458786 -0.971863
# elizabeth Romford Rail Station 910GROMFORD None Romford Rail Station 51.574829 0.183237
# elizabeth Shenfield Rail Station 910GSHENFLD None Shenfield Rail Station 51.630877 0.329851
# elizabeth Slough Rail Station 910GSLOUGH None Slough Rail Station 51.51188 -0.59151
# elizabeth Stratford (London) Rail Station 910GSTFD HUBSRA None 51.541895 -0.003397
# elizabeth Southall Rail Station 910GSTHALL None Southall Rail Station 51.505957 -0.37861
# elizabeth Seven Kings Rail Station 910GSVNKNGS None Seven Kings Rail Station 51.564026 0.0971
# elizabeth Taplow Rail Station 910GTAPLOW None Taplow Rail Station 51.523562 -0.68137
# elizabeth Tottenham Court Road 910GTOTCTRD HUBTCR None 51.515974 -0.130241
# elizabeth Twyford Rail Station 910GTWYFORD None Twyford Rail Station 51.475534 -0.863293
# elizabeth Whitechapel 910GWCHAPXR HUBZWL None 51.51943 -0.060191
# elizabeth West Drayton Rail Station 910GWDRYTON None West Drayton Rail Station 51.510055 -0.472234
# elizabeth West Ealing Rail Station 910GWEALING None West Ealing Rail Station 51.513506 -0.320133
# elizabeth Woolwich 910GWOLWXR None Woolwich 51.49119 0.07072
# hammersmith-city Aldgate East Underground Station 940GZZLUADE None Aldgate East Underground Station 51.515037 -0.072384
# hammersmith-city Bromley-by-Bow Underground Station 940GZZLUBBB None Bromley-by-Bow Underground Station 51.524839 -0.011538
# hammersmith-city Barbican Underground Station 940GZZLUBBN None Barbican Underground Station 51.520275 -0.097993
# hammersmith-city Barking Underground Station 940GZZLUBKG HUBBKG None 51.539321 0.081053
# hammersmith-city Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station 51.522883 -0.15713
# hammersmith-city Bow Road Underground Station 940GZZLUBWR None Bow Road Underground Station 51.52694 -0.025128
# hammersmith-city East Ham Underground Station 940GZZLUEHM None East Ham Underground Station 51.538948 0.051186
# hammersmith-city Edgware Road (Circle Line) Underground Station 940GZZLUERC None Edgware Road (Circle Line) Underground Station 51.519858 -0.167832
# hammersmith-city Euston Square Underground Station 940GZZLUESQ None Euston Square Underground Station 51.525604 -0.135829
# hammersmith-city Farringdon Underground Station 940GZZLUFCN HUBZFD None 51.520252 -0.104913
# hammersmith-city Goldhawk Road Underground Station 940GZZLUGHK None Goldhawk Road Underground Station 51.502005 -0.226715
# hammersmith-city Great Portland Street Underground Station 940GZZLUGPS None Great Portland Street Underground Station 51.52384 -0.144262
# hammersmith-city Hammersmith (H&C Line) Underground Station 940GZZLUHSC HUBHMS None 51.49339 -0.22503
# hammersmith-city King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None 51.530663 -0.123194
# hammersmith-city Ladbroke Grove Underground Station 940GZZLULAD None Ladbroke Grove Underground Station 51.517449 -0.210391
# hammersmith-city Latimer Road Underground Station 940GZZLULRD None Latimer Road Underground Station 51.513389 -0.217799
# hammersmith-city Liverpool Street Underground Station 940GZZLULVT HUBLST None 51.517372 -0.083182
# hammersmith-city Mile End Underground Station 940GZZLUMED None Mile End Underground Station 51.525122 -0.03364
# hammersmith-city Moorgate Underground Station 940GZZLUMGT HUBZMG None 51.518176 -0.088322
# hammersmith-city Paddington (H&C Line)-Underground 940GZZLUPAH HUBPAD None 51.518187 -0.178306
# hammersmith-city Plaistow Underground Station 940GZZLUPLW None Plaistow Underground Station 51.531341 0.017451
# hammersmith-city Royal Oak Underground Station 940GZZLURYO None Royal Oak Underground Station 51.519113 -0.188748
# hammersmith-city Shepherd's Bush Market Underground Station 940GZZLUSBM None Shepherd's Bush Market Underground Station 51.505579 -0.226375
# hammersmith-city Stepney Green Underground Station 940GZZLUSGN None Stepney Green Underground Station 51.521858 -0.046596
# hammersmith-city Upton Park Underground Station 940GZZLUUPK None Upton Park Underground Station 51.53534 0.035263
# hammersmith-city West Ham Underground Station 940GZZLUWHM HUBWEH None 51.528136 0.005055
# hammersmith-city Wood Lane Underground Station 940GZZLUWLA None Wood Lane Underground Station 51.509669 -0.22453
# hammersmith-city Whitechapel Underground Station 940GZZLUWPL HUBZWL None 51.519518 -0.059971
# hammersmith-city Westbourne Park Underground Station 940GZZLUWSP None Westbourne Park Underground Station 51.52111 -0.201065
# jubilee Bermondsey Underground Station 940GZZLUBMY None Bermondsey Underground Station 51.49775 -0.063993
# jubilee Bond Street Underground Station 940GZZLUBND HUBBDS None 51.514304 -0.149723
# jubilee Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station 51.522883 -0.15713
# jubilee Canning Town Underground Station 940GZZLUCGT HUBCAN None 51.513584 0.008322
# jubilee Canons Park Underground Station 940GZZLUCPK None Canons Park Underground Station 51.607701 -0.294693
# jubilee Canada Water Underground Station 940GZZLUCWR HUBZCW None 51.497931 -0.049405
# jubilee Canary Wharf Underground Station 940GZZLUCYF HUBCAW None 51.503488 -0.018246
# jubilee Dollis Hill Underground Station 940GZZLUDOH None Dollis Hill Underground Station 51.551955 -0.239068
# jubilee Finchley Road Underground Station 940GZZLUFYR None Finchley Road Underground Station 51.546825 -0.179845
# jubilee Green Park Underground Station 940GZZLUGPK None Green Park Underground Station 51.506947 -0.142787
# jubilee Kilburn Underground Station 940GZZLUKBN None Kilburn Underground Station 51.547183 -0.204248
# jubilee Kingsbury Underground Station 940GZZLUKBY None Kingsbury Underground Station 51.584845 -0.27879
# jubilee London Bridge Underground Station 940GZZLULNB HUBLBG None 51.505721 -0.088873
# jubilee Neasden Underground Station 940GZZLUNDN None Neasden Underground Station 51.553986 -0.249837
# jubilee North Greenwich Underground Station 940GZZLUNGW HUBNGW None 51.50047 0.004287
# jubilee Queensbury Underground Station 940GZZLUQBY None Queensbury Underground Station 51.594188 -0.286219
# jubilee St. John's Wood Underground Station 940GZZLUSJW None St. John's Wood Underground Station 51.534521 -0.173948
# jubilee Stratford Underground Station 940GZZLUSTD HUBSRA None 51.541806 -0.003458
# jubilee Stanmore Underground Station 940GZZLUSTM None Stanmore Underground Station 51.619839 -0.303266
# jubilee Swiss Cottage Underground Station 940GZZLUSWC None Swiss Cottage Underground Station 51.543681 -0.174894
# jubilee Southwark Underground Station 940GZZLUSWK None Southwark Underground Station 51.50427 -0.105331
# jubilee West Ham Underground Station 940GZZLUWHM HUBWEH None 51.528136 0.005055
# jubilee West Hampstead Underground Station 940GZZLUWHP HUBWHD None 51.546638 -0.191059
# jubilee Willesden Green Underground Station 940GZZLUWIG None Willesden Green Underground Station 51.549146 -0.221537
# jubilee Waterloo Underground Station 940GZZLUWLO HUBWAT None 51.503299 -0.11478
# jubilee Westminster Underground Station 940GZZLUWSM HUBWSM None 51.50132 -0.124861
# jubilee Wembley Park Underground Station 940GZZLUWYP None Wembley Park Underground Station 51.563198 -0.279262
# liberty Emerson Park Rail Station 910GEMRSPKH None Emerson Park Rail Station 51.568642 0.220113
# liberty Romford Rail Station 910GROMFORD None Romford Rail Station 51.574829 0.183237
# liberty Upminster Rail Station 910GUPMNSTR HUBUPM None 51.559018 0.25088
# lioness Bushey Rail Station 910GBUSHYDC HUBBSH None 51.645691 -0.385612
# lioness Carpenders Park Rail Station 910GCRPNDPK None Carpenders Park Rail Station 51.628351 -0.385939
# lioness London Euston Rail Station 910GEUSTON HUBEUS None 51.528136 -0.133924
# lioness Harlesden Rail Station 910GHARLSDN HUBHDN None 51.536289 -0.257667
# lioness Headstone Lane Rail Station 910GHEDSTNL None Headstone Lane Rail Station 51.602649 -0.35722
# lioness Harrow & Wealdstone Rail Station 910GHROW HUBHRW None 51.592169 -0.334571
# lioness Hatch End Rail Station 910GHTCHEND None Hatch End Rail Station 51.609417 -0.368601
# lioness Kensal Green Rail Station 910GKENSLG HUBKNL None 51.53054 -0.225088
# lioness Kilburn High Road Rail Station 910GKLBRNHR None Kilburn High Road Rail Station 51.537277 -0.192237
# lioness Kenton Rail Station 910GKTON HUBKNT None 51.581802 -0.316981
# lioness North Wembley Rail Station 910GNWEMBLY HUBNWB None 51.562596 -0.303984
# lioness Queens Park (London) Rail Station 910GQPRK HUBQPW None 51.533966 -0.204985
# lioness South Hampstead Rail Station 910GSHMPSTD None South Hampstead Rail Station 51.541432 -0.178878
# lioness South Kenton Rail Station 910GSKENTON HUBSOK None 51.570214 -0.308462
# lioness Stonebridge Park Rail Station 910GSTNBGPK HUBSBP None 51.544111 -0.275828
# lioness Watford High Street Rail Station 910GWATFDHS None Watford High Street Rail Station 51.652655 -0.391711
# lioness Watford Junction Rail Station 910GWATFJDC HUBWFJ None 51.663529 -0.396517
# lioness Willesden Junction Rail Station 910GWLSDJHL HUBWIJ None 51.532497 -0.244548
# lioness Wembley Central Rail Station 910GWMBY HUBWMB None 51.552325 -0.296433
# metropolitan Aldgate Underground Station 940GZZLUALD None Aldgate Underground Station 51.514246 -0.075689
# metropolitan Amersham Underground Station 940GZZLUAMS HUBAMR None 51.674126 -0.607714
# metropolitan Barbican Underground Station 940GZZLUBBN None Barbican Underground Station 51.520275 -0.097993
# metropolitan Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station 51.522883 -0.15713
# metropolitan Chalfont & Latimer Underground Station 940GZZLUCAL HUBCFO None 51.667985 -0.560689
# metropolitan Chesham Underground Station 940GZZLUCSM None Chesham Underground Station 51.705208 -0.611247
# metropolitan Croxley Underground Station 940GZZLUCXY None Croxley Underground Station 51.647044 -0.441718
# metropolitan Chorleywood Underground Station 940GZZLUCYD HUBCLW None 51.654358 -0.518461
# metropolitan Eastcote Underground Station 940GZZLUEAE None Eastcote Underground Station 51.576506 -0.397373
# metropolitan Euston Square Underground Station 940GZZLUESQ None Euston Square Underground Station 51.525604 -0.135829
# metropolitan Farringdon Underground Station 940GZZLUFCN HUBZFD None 51.520252 -0.104913
# metropolitan Finchley Road Underground Station 940GZZLUFYR None Finchley Road Underground Station 51.546825 -0.179845
# metropolitan Great Portland Street Underground Station 940GZZLUGPS None Great Portland Street Underground Station 51.52384 -0.144262
# metropolitan Hillingdon Underground Station 940GZZLUHGD None Hillingdon Underground Station 51.553715 -0.449828
# metropolitan Harrow-on-the-Hill Underground Station 940GZZLUHOH HUBHOH None 51.579195 -0.337225
# metropolitan Ickenham Underground Station 940GZZLUICK None Ickenham Underground Station 51.561992 -0.442001
# metropolitan King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None 51.530663 -0.123194
# metropolitan Liverpool Street Underground Station 940GZZLULVT HUBLST None 51.517372 -0.083182
# metropolitan Moorgate Underground Station 940GZZLUMGT HUBZMG None 51.518176 -0.088322
# metropolitan Moor Park Underground Station 940GZZLUMPK None Moor Park Underground Station 51.629845 -0.432454
# metropolitan North Harrow Underground Station 940GZZLUNHA None North Harrow Underground Station 51.584872 -0.362408
# metropolitan Northwick Park Underground Station 940GZZLUNKP None Northwick Park Underground Station 51.578481 -0.318056
# metropolitan Northwood Underground Station 940GZZLUNOW None Northwood Underground Station 51.611053 -0.423829
# metropolitan Northwood Hills Underground Station 940GZZLUNWH None Northwood Hills Underground Station 51.600572 -0.409464
# metropolitan Pinner Underground Station 940GZZLUPNR None Pinner Underground Station 51.592901 -0.381161
# metropolitan Preston Road Underground Station 940GZZLUPRD None Preston Road Underground Station 51.571972 -0.295107
# metropolitan Rickmansworth Underground Station 940GZZLURKW HUBRIC None 51.640207 -0.473703
# metropolitan Ruislip Manor Underground Station 940GZZLURSM None Ruislip Manor Underground Station 51.573202 -0.412973
# metropolitan Ruislip Underground Station 940GZZLURSP None Ruislip Underground Station 51.571354 -0.421898
# metropolitan Rayners Lane Underground Station 940GZZLURYL None Rayners Lane Underground Station 51.575147 -0.371127
# metropolitan Uxbridge Underground Station 940GZZLUUXB None Uxbridge Underground Station 51.546565 -0.477949
# metropolitan Watford Underground Station 940GZZLUWAF None Watford Underground Station 51.657446 -0.417377
# metropolitan West Harrow Underground Station 940GZZLUWHW None West Harrow Underground Station 51.57971 -0.3534
# metropolitan Wembley Park Underground Station 940GZZLUWYP None Wembley Park Underground Station 51.563198 -0.279262
# mildmay Acton Central Rail Station 910GACTNCTL None Acton Central Rail Station 51.508716 -0.262971
# mildmay Brondesbury Rail Station 910GBRBY None Brondesbury Rail Station 51.545166 -0.202309
# mildmay Brondesbury Park Rail Station 910GBRBYPK None Brondesbury Park Rail Station 51.540734 -0.210054
# mildmay Caledonian Road & Barnsbury Rail Station 910GCLDNNRB None Caledonian Road & Barnsbury Rail Station 51.543041 -0.116729
# mildmay Clapham Junction Rail Station 910GCLPHMJ1 HUBCLJ None 51.464187 -0.170221
# mildmay Clapham Junction Rail Station 910GCLPHMJC HUBCLJ None 51.464188 -0.170293
# mildmay Camden Road Rail Station 910GCMDNRD None Camden Road Rail Station 51.541791 -0.138701
# mildmay Canonbury Rail Station 910GCNNB None Canonbury Rail Station 51.548732 -0.092191
# mildmay Imperial Wharf Rail Station 910GCSEAH HUBIMP None 51.474949 -0.182823
# mildmay Dalston Kingsland Rail Station 910GDALSKLD None Dalston Kingsland Rail Station 51.548148 -0.075701
# mildmay Finchley Road & Frognal Rail Station 910GFNCHLYR None Finchley Road & Frognal Rail Station 51.550266 -0.183141
# mildmay Gunnersbury Rail Station 910GGNRSBRY HUBGUN None 51.491678 -0.275286
# mildmay Gospel Oak Rail Station 910GGOSPLOK None Gospel Oak Rail Station 51.555335 -0.15077
# mildmay Hackney Central Rail Station 910GHACKNYC None Hackney Central Rail Station 51.547105 -0.056058
# mildmay Hackney Wick Rail Station 910GHACKNYW None Hackney Wick Rail Station 51.54341 -0.02492
# mildmay Highbury & Islington Rail Station 910GHGHI HUBHHY None 51.546177 -0.103764
# mildmay Hampstead Heath Rail Station 910GHMPSTDH None Hampstead Heath Rail Station 51.55521 -0.165705
# mildmay Homerton Rail Station 910GHOMRTON None Homerton Rail Station 51.547012 -0.04236
# mildmay Kensington (Olympia) Rail Station 910GKENOLYM HUBKPA None 51.497899 -0.210364
# mildmay Kensal Rise Rail Station 910GKENR None Kensal Rise Rail Station 51.534554 -0.219957
# mildmay Kew Gardens Rail Station 910GKEWGRDN HUBKWG None 51.477073 -0.285054
# mildmay Kentish Town West Rail Station 910GKNTSHTW None Kentish Town West Rail Station 51.546548 -0.146655
# mildmay Richmond (London) Rail Station 910GRICHMND HUBRMD None 51.463061 -0.301558
# mildmay South Acton Rail Station 910GSACTON None South Acton Rail Station 51.499695 -0.270157
# mildmay Shepherds Bush Rail Station 910GSHPDSB HUBSPB None 51.505285 -0.217654
# mildmay Stratford (London) Rail Station 910GSTFD HUBSRA None 51.541895 -0.003397
# mildmay West Brompton Rail Station 910GWBRMPTN HUBWBP None 51.487061 -0.195593
# mildmay West Hampstead Rail Station 910GWHMDSTD HUBWHD None 51.547468 -0.191185
# mildmay Willesden Junction Rail Station 910GWLSDJHL HUBWIJ None 51.532497 -0.244548
# northern Battersea Power Station Underground Station 940GZZBPSUST None Battersea Power Station Underground Station 51.479932 -0.142142
# northern Archway Underground Station 940GZZLUACY None Archway Underground Station 51.565478 -0.134819
# northern Angel Underground Station 940GZZLUAGL None Angel Underground Station 51.532624 -0.105898
# northern Balham Underground Station 940GZZLUBLM HUBBAL None 51.443288 -0.152997
# northern Bank Underground Station 940GZZLUBNK HUBBAN None 51.513132 -0.090047
# northern Borough Underground Station 940GZZLUBOR None Borough Underground Station 51.501199 -0.09337
# northern Burnt Oak Underground Station 940GZZLUBTK None Burnt Oak Underground Station 51.602774 -0.264048
# northern Brent Cross Underground Station 940GZZLUBTX None Brent Cross Underground Station 51.57665 -0.213622
# northern Belsize Park Underground Station 940GZZLUBZP None Belsize Park Underground Station 51.550529 -0.164783
# northern Chalk Farm Underground Station 940GZZLUCFM None Chalk Farm Underground Station 51.544118 -0.153388
# northern Charing Cross Underground Station 940GZZLUCHX HUBCHX None 51.50741 -0.127277
# northern Colindale Underground Station 940GZZLUCND None Colindale Underground Station 51.595424 -0.249919
# northern Clapham Common Underground Station 940GZZLUCPC None Clapham Common Underground Station 51.461742 -0.138317
# northern Clapham North Underground Station 940GZZLUCPN None Clapham North Underground Station 51.465135 -0.130016
# northern Clapham South Underground Station 940GZZLUCPS None Clapham South Underground Station 51.452654 -0.147582
# northern Colliers Wood Underground Station 940GZZLUCSD None Colliers Wood Underground Station 51.41816 -0.178086
# northern Camden Town Underground Station 940GZZLUCTN None Camden Town Underground Station 51.539292 -0.14274
# northern Elephant & Castle Underground Station 940GZZLUEAC HUBEPH None 51.494536 -0.100606
# northern East Finchley Underground Station 940GZZLUEFY None East Finchley Underground Station 51.587131 -0.165012
# northern Edgware Underground Station 940GZZLUEGW None Edgware Underground Station 51.613653 -0.274928
# northern Embankment Underground Station 940GZZLUEMB None Embankment Underground Station 51.507058 -0.122666
# northern Euston Underground Station 940GZZLUEUS HUBEUS None 51.528055 -0.132182
# northern Finchley Central Underground Station 940GZZLUFYC None Finchley Central Underground Station 51.600921 -0.192527
# northern Goodge Street Underground Station 940GZZLUGDG None Goodge Street Underground Station 51.520599 -0.134361
# northern Golders Green Underground Station 940GZZLUGGN None Golders Green Underground Station 51.572259 -0.194039
# northern High Barnet Underground Station 940GZZLUHBT None High Barnet Underground Station 51.650541 -0.194298
# northern Hendon Central Underground Station 940GZZLUHCL None Hendon Central Underground Station 51.583301 -0.226424
# northern Highgate Underground Station 940GZZLUHGT None Highgate Underground Station 51.577532 -0.145857
# northern Hampstead Underground Station 940GZZLUHTD None Hampstead Underground Station 51.556239 -0.177464
# northern Kennington Underground Station 940GZZLUKNG None Kennington Underground Station 51.488337 -0.105963
# northern Kentish Town Underground Station 940GZZLUKSH HUBKTN None 51.550312 -0.140733
# northern King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None 51.530663 -0.123194
# northern London Bridge Underground Station 940GZZLULNB HUBLBG None 51.505721 -0.088873
# northern Leicester Square Underground Station 940GZZLULSQ None Leicester Square Underground Station 51.511386 -0.128426
# northern Morden Underground Station 940GZZLUMDN None Morden Underground Station 51.402142 -0.194839
# northern Moorgate Underground Station 940GZZLUMGT HUBZMG None 51.518176 -0.088322
# northern Mill Hill East Underground Station 940GZZLUMHL None Mill Hill East Underground Station 51.608229 -0.209986
# northern Mornington Crescent Underground Station 940GZZLUMTC None Mornington Crescent Underground Station 51.534679 -0.138789
# northern Old Street Underground Station 940GZZLUODS HUBOLD None 51.525864 -0.08777
# northern Oval Underground Station 940GZZLUOVL None Oval Underground Station 51.48185 -0.112439
# northern Stockwell Underground Station 940GZZLUSKW None Stockwell Underground Station 51.472184 -0.122644
# northern South Wimbledon Underground Station 940GZZLUSWN None South Wimbledon Underground Station 51.415309 -0.192005
# northern Totteridge & Whetstone Underground Station 940GZZLUTAW None Totteridge & Whetstone Underground Station 51.630597 -0.17921
# northern Tooting Bec Underground Station 940GZZLUTBC None Tooting Bec Underground Station 51.435678 -0.159736
# northern Tooting Broadway Underground Station 940GZZLUTBY None Tooting Broadway Underground Station 51.42763 -0.168374
# northern Tottenham Court Road Underground Station 940GZZLUTCR HUBTCR None 51.516426 -0.13041
# northern Tufnell Park Underground Station 940GZZLUTFP None Tufnell Park Underground Station 51.556822 -0.138433
# northern West Finchley Underground Station 940GZZLUWFN None West Finchley Underground Station 51.609426 -0.188362
# northern Waterloo Underground Station 940GZZLUWLO HUBWAT None 51.503299 -0.11478
# northern Woodside Park Underground Station 940GZZLUWOP None Woodside Park Underground Station 51.618014 -0.18542
# northern Warren Street Underground Station 940GZZLUWRR None Warren Street Underground Station 51.524951 -0.138321
# northern Nine Elms Underground Station 940GZZNEUGST None Nine Elms Underground Station 51.479912 -0.128476
# piccadilly Acton Town Underground Station 940GZZLUACT None Acton Town Underground Station 51.503057 -0.280462
# piccadilly Alperton Underground Station 940GZZLUALP None Alperton Underground Station 51.540627 -0.29961
# piccadilly Arnos Grove Underground Station 940GZZLUASG None Arnos Grove Underground Station 51.616446 -0.133062
# piccadilly Arsenal Underground Station 940GZZLUASL None Arsenal Underground Station 51.558655 -0.107457
# piccadilly Bounds Green Underground Station 940GZZLUBDS None Bounds Green Underground Station 51.607034 -0.124235
# piccadilly Boston Manor Underground Station 940GZZLUBOS None Boston Manor Underground Station 51.495635 -0.324939
# piccadilly Barons Court Underground Station 940GZZLUBSC None Barons Court Underground Station 51.490311 -0.213427
# piccadilly Caledonian Road Underground Station 940GZZLUCAR None Caledonian Road Underground Station 51.548519 -0.118493
# piccadilly Covent Garden Underground Station 940GZZLUCGN None Covent Garden Underground Station 51.513093 -0.124436
# piccadilly Cockfosters Underground Station 940GZZLUCKS None Cockfosters Underground Station 51.65152 -0.149171
# piccadilly Eastcote Underground Station 940GZZLUEAE None Eastcote Underground Station 51.576506 -0.397373
# piccadilly Ealing Common Underground Station 940GZZLUECM None Ealing Common Underground Station 51.51014 -0.288265
# piccadilly Earl's Court Underground Station 940GZZLUECT None Earl's Court Underground Station 51.492063 -0.193378
# piccadilly Finsbury Park Underground Station 940GZZLUFPK HUBFPK None 51.564158 -0.106825
# piccadilly Green Park Underground Station 940GZZLUGPK None Green Park Underground Station 51.506947 -0.142787
# piccadilly Gloucester Road Underground Station 940GZZLUGTR None Gloucester Road Underground Station 51.494316 -0.182658
# piccadilly Holborn Underground Station 940GZZLUHBN None Holborn Underground Station 51.51758 -0.120475
# piccadilly Hillingdon Underground Station 940GZZLUHGD None Hillingdon Underground Station 51.553715 -0.449828
# piccadilly Hatton Cross Underground Station 940GZZLUHNX None Hatton Cross Underground Station 51.466747 -0.423191
# piccadilly Hyde Park Corner Underground Station 940GZZLUHPC None Hyde Park Corner Underground Station 51.503035 -0.152441
# piccadilly Heathrow Terminal 4 Underground Station 940GZZLUHR4 HUBHX4 None 51.458524 -0.445771
# piccadilly Heathrow Terminal 5 Underground Station 940GZZLUHR5 HUBHX5 None 51.470052 -0.49056
# piccadilly Heathrow Terminals 2 & 3 Underground Station 940GZZLUHRC HUBH13 None 51.471235 -0.452265
# piccadilly Hammersmith (Dist&Picc Line) Underground Station 940GZZLUHSD HUBHMS None 51.4923 -0.22362
# piccadilly Hounslow Central Underground Station 940GZZLUHWC None Hounslow Central Underground Station 51.471295 -0.366578
# piccadilly Hounslow East Underground Station 940GZZLUHWE None Hounslow East Underground Station 51.473213 -0.356474
# piccadilly Hounslow West Underground Station 940GZZLUHWT None Hounslow West Underground Station 51.473469 -0.386544
# piccadilly Holloway Road Underground Station 940GZZLUHWY None Holloway Road Underground Station 51.552697 -0.113244
# piccadilly Ickenham Underground Station 940GZZLUICK None Ickenham Underground Station 51.561992 -0.442001
# piccadilly Knightsbridge Underground Station 940GZZLUKNB None Knightsbridge Underground Station 51.501669 -0.160508
# ...
# North Harrow Underground Station - 940GZZLUNHA - metropolitan = None
# North Wembley Rail Station - 910GNWEMBLY - lioness = HUBNWB
# North Wembley Underground Station - 940GZZLUNWY - bakerloo = HUBNWB
# Northfields Underground Station - 940GZZLUNFD - piccadilly = None
# Northolt Underground Station - 940GZZLUNHT - central = None
# Northwick Park Underground Station - 940GZZLUNKP - metropolitan = None
# Northwood Hills Underground Station - 940GZZLUNWH - metropolitan = None
# Northwood Underground Station - 940GZZLUNOW - metropolitan = None
# Norwood Junction Rail Station - 910GNORWDJ - windrush = HUBNWD
# Notting Hill Gate Underground Station - 940GZZLUNHG - central = None
# Notting Hill Gate Underground Station - 940GZZLUNHG - circle = None
# Notting Hill Gate Underground Station - 940GZZLUNHG - district = None
# Oakwood Underground Station - 940GZZLUOAK - piccadilly = None
# Old Street Underground Station - 940GZZLUODS - northern = HUBOLD
# Osterley Underground Station - 940GZZLUOSY - piccadilly = None
# Oval Underground Station - 940GZZLUOVL - northern = None
# Oxford Circus Underground Station - 940GZZLUOXC - bakerloo = None
# Oxford Circus Underground Station - 940GZZLUOXC - central = None
# Oxford Circus Underground Station - 940GZZLUOXC - victoria = None
# Paddington (H&C Line)-Underground - 940GZZLUPAH - circle = HUBPAD
# Paddington (H&C Line)-Underground - 940GZZLUPAH - hammersmith-city = HUBPAD
# Paddington - 910GPADTLL - elizabeth = HUBPAD
# Paddington Underground Station - 940GZZLUPAC - bakerloo = HUBPAD
# Paddington Underground Station - 940GZZLUPAC - circle = HUBPAD
# Paddington Underground Station - 940GZZLUPAC - district = HUBPAD
# Park Royal Underground Station - 940GZZLUPKR - piccadilly = None
# Parsons Green Underground Station - 940GZZLUPSG - district = None
# Peckham Rye Rail Station - 910GPCKHMRY - windrush = None
# Penge West Rail Station - 910GPENEW - windrush = None
# Perivale Underground Station - 940GZZLUPVL - central = None
# Phipps Bridge - 940GZZCRPHI - tram = None
# Phipps Bridge - 940GZZCRPHI - tram = None
# Phipps Bridge Tram Stop - 940GZZCRPHI - tram = None
# Piccadilly Circus Underground Station - 940GZZLUPCC - bakerloo = None
# Piccadilly Circus Underground Station - 940GZZLUPCC - piccadilly = None
# Pimlico Underground Station - 940GZZLUPCO - victoria = None
# Pinner Underground Station - 940GZZLUPNR - metropolitan = None
# Plaistow Underground Station - 940GZZLUPLW - district = None
# Plaistow Underground Station - 940GZZLUPLW - hammersmith-city = None
# Pontoon Dock DLR Station - 940GZZDLPDK - dlr = None
# Poplar DLR Station - 940GZZDLPOP - dlr = None
# Preston Road Underground Station - 940GZZLUPRD - metropolitan = None
# Prince Regent DLR Station - 940GZZDLPRE - dlr = None
# Pudding Mill Lane DLR Station - 940GZZDLPUD - dlr = None
# Putney Bridge Underground Station - 940GZZLUPYB - district = None
# Queen's Park Underground Station - 940GZZLUQPS - bakerloo = HUBQPW
# Queens Park (London) Rail Station - 910GQPRK - lioness = HUBQPW
# Queens Road Peckham Rail Station - 910GPCKHMQD - windrush = None
# Queensbury Underground Station - 940GZZLUQBY - jubilee = None
# Queensway Underground Station - 940GZZLUQWY - central = None
# Ravenscourt Park Underground Station - 940GZZLURVP - district = None
# Rayners Lane Underground Station - 940GZZLURYL - metropolitan = None
# Rayners Lane Underground Station - 940GZZLURYL - piccadilly = None
# Reading Rail Station - 910GRDNGSTN - elizabeth = None
# Rectory Road Rail Station - 910GRCTRYRD - weaver = None
# Redbridge Underground Station - 940GZZLURBG - central = None
# Reeves Corner - 940GZZCRRVC - tram = None
# Reeves Corner Tram Stop - 940GZZCRRVC - tram = None
# Regent's Park Underground Station - 940GZZLURGP - bakerloo = None
# Richmond (London) Rail Station - 910GRICHMND - mildmay = HUBRMD
# Richmond Underground Station - 940GZZLURMD - district = HUBRMD
# Rickmansworth Underground Station - 940GZZLURKW - metropolitan = HUBRIC
# Roding Valley Underground Station - 940GZZLURVY - central = None
# Romford Rail Station - 910GROMFORD - elizabeth = None
# Romford Rail Station - 910GROMFORD - liberty = None
# Rotherhithe Rail Station - 910GRTHERHI - windrush = None
# Royal Albert DLR Station - 940GZZDLRAL - dlr = None
# Royal Oak Underground Station - 940GZZLURYO - circle = None
# Royal Oak Underground Station - 940GZZLURYO - hammersmith-city = None
# Royal Victoria DLR Station - 940GZZDLRVC - dlr = HUBRVC
# Ruislip Gardens Underground Station - 940GZZLURSG - central = None
# Ruislip Manor Underground Station - 940GZZLURSM - metropolitan = None
# Ruislip Manor Underground Station - 940GZZLURSM - piccadilly = None
# Ruislip Underground Station - 940GZZLURSP - metropolitan = None
# Ruislip Underground Station - 940GZZLURSP - piccadilly = None
# Russell Square Underground Station - 940GZZLURSQ - piccadilly = None
# Sandilands - 940GZZCRSAN - tram = None
# Sandilands - 940GZZCRSAN - tram = None
# Sandilands Tram Stop - 940GZZCRSAN - tram = None
# Seven Kings Rail Station - 910GSVNKNGS - elizabeth = None
# Seven Sisters Rail Station - 910GSEVNSIS - weaver = HUBSVS
# Seven Sisters Underground Station - 940GZZLUSVS - victoria = HUBSVS
# Shadwell DLR Station - 940GZZDLSHA - dlr = HUBSDE
# Shadwell Rail Station - 910GSHADWEL - windrush = HUBSDE
# Shenfield Rail Station - 910GSHENFLD - elizabeth = None
# Shepherd's Bush (Central) Underground Station - 940GZZLUSBC - central = HUBSPB
# Shepherd's Bush Market Underground Station - 940GZZLUSBM - circle = None
# Shepherd's Bush Market Underground Station - 940GZZLUSBM - hammersmith-city = None
# Shepherds Bush Rail Station - 910GSHPDSB - mildmay = HUBSPB
# Shoreditch High Street Rail Station - 910GSHRDHST - windrush = None
# Silver Street Rail Station - 910GSIVRST - weaver = None
# Sloane Square Underground Station - 940GZZLUSSQ - circle = None
# Sloane Square Underground Station - 940GZZLUSSQ - district = None
# Slough Rail Station - 910GSLOUGH - elizabeth = None
# Snaresbrook Underground Station - 940GZZLUSNB - central = None
# South Acton Rail Station - 910GSACTON - mildmay = None
# South Ealing Underground Station - 940GZZLUSEA - piccadilly = None
# South Hampstead Rail Station - 910GSHMPSTD - lioness = None
# South Harrow Underground Station - 940GZZLUSHH - piccadilly = None
# South Kensington Underground Station - 940GZZLUSKS - circle = None
# South Kensington Underground Station - 940GZZLUSKS - district = None
# South Kensington Underground Station - 940GZZLUSKS - piccadilly = None
# South Kenton Rail Station - 910GSKENTON - lioness = HUBSOK
# South Kenton Underground Station - 940GZZLUSKT - bakerloo = HUBSOK
# South Quay DLR Station - 940GZZDLSOQ - dlr = None
# South Ruislip Underground Station - 940GZZLUSRP - central = HUBSRU
# South Tottenham Rail Station - 910GSTOTNHM - suffragette = None
# South Wimbledon Underground Station - 940GZZLUSWN - northern = None
# South Woodford Underground Station - 940GZZLUSWF - central = None
# Southall Rail Station - 910GSTHALL - elizabeth = None
# Southbury Rail Station - 910GSBURY - weaver = None
# Southfields Underground Station - 940GZZLUSFS - district = None
# Southgate Underground Station - 940GZZLUSGT - piccadilly = None
# Southwark Underground Station - 940GZZLUSWK - jubilee = None
# St James Street (London) Rail Station - 910GSTJMSST - weaver = None
# St. James's Park Underground Station - 940GZZLUSJP - circle = None
# St. James's Park Underground Station - 940GZZLUSJP - district = None
# St. John's Wood Underground Station - 940GZZLUSJW - jubilee = None
# St. Paul's Underground Station - 940GZZLUSPU - central = None
# Stamford Brook Underground Station - 940GZZLUSFB - district = None
# Stamford Hill Rail Station - 910GSTMFDHL - weaver = None
# Stanmore Underground Station - 940GZZLUSTM - jubilee = None
# Star Lane DLR Station - 940GZZDLSTL - dlr = None
# Stepney Green Underground Station - 940GZZLUSGN - district = None
# Stepney Green Underground Station - 940GZZLUSGN - hammersmith-city = None
# Stockwell Underground Station - 940GZZLUSKW - northern = None
# Stockwell Underground Station - 940GZZLUSKW - victoria = None
# Stoke Newington Rail Station - 910GSTKNWNG - weaver = None
# Stonebridge Park Rail Station - 910GSTNBGPK - lioness = HUBSBP
# Stonebridge Park Underground Station - 940GZZLUSGP - bakerloo = HUBSBP
# Stratford (London) Rail Station - 910GSTFD - elizabeth = HUBSRA
# Stratford (London) Rail Station - 910GSTFD - mildmay = HUBSRA
# Stratford DLR Station - 940GZZDLSTD - dlr = HUBSRA
# Stratford High Street DLR Station - 940GZZDLSHS - dlr = None
# Stratford International DLR Station - 940GZZDLSIT - dlr = None
# Stratford Underground Station - 940GZZLUSTD - central = HUBSRA
# Stratford Underground Station - 940GZZLUSTD - jubilee = HUBSRA
# Sudbury Hill Underground Station - 940GZZLUSUH - piccadilly = None
# Sudbury Town Underground Station - 940GZZLUSUT - piccadilly = None
# Surrey Quays Rail Station - 910GSURREYQ - windrush = None
# Swiss Cottage Underground Station - 940GZZLUSWC - jubilee = None
# Sydenham Rail Station - 910GSYDENHM - windrush = HUBSYD
# Taplow Rail Station - 910GTAPLOW - elizabeth = None
# Temple Underground Station - 940GZZLUTMP - circle = None
# Temple Underground Station - 940GZZLUTMP - district = None
# Theobalds Grove Rail Station - 910GTHBLDSG - weaver = None
# Therapia Lane - 940GZZCRTPA - tram = None
# Therapia Lane - 940GZZCRTPA - tram = None
# Therapia Lane Tram Stop - 940GZZCRTPA - tram = None
# Theydon Bois Underground Station - 940GZZLUTHB - central = None
# Tooting Bec Underground Station - 940GZZLUTBC - northern = None
# Tooting Broadway Underground Station - 940GZZLUTBY - northern = None
# Tottenham Court Road - 910GTOTCTRD - elizabeth = HUBTCR
# Tottenham Court Road Underground Station - 940GZZLUTCR - central = HUBTCR
# Tottenham Court Road Underground Station - 940GZZLUTCR - northern = HUBTCR
# Tottenham Hale Underground Station - 940GZZLUTMH - victoria = HUBTOM
# Totteridge & Whetstone Underground Station - 940GZZLUTAW - northern = None
# Tower Gateway DLR Station - 940GZZDLTWG - dlr = HUBTOG
# Tower Hill Underground Station - 940GZZLUTWH - circle = None
# Tower Hill Underground Station - 940GZZLUTWH - district = None
# Tufnell Park Underground Station - 940GZZLUTFP - northern = None
# Turkey Street Rail Station - 910GTURKYST - weaver = None
# Turnham Green Underground Station - 940GZZLUTNG - district = None
# Turnham Green Underground Station - 940GZZLUTNG - piccadilly = None
# Turnpike Lane Underground Station - 940GZZLUTPN - piccadilly = None
# Twyford Rail Station - 910GTWYFORD - elizabeth = None
# Upminster Bridge Underground Station - 940GZZLUUPB - district = None
# Upminster Rail Station - 910GUPMNSTR - liberty = HUBUPM
# Upminster Underground Station - 940GZZLUUPM - district = HUBUPM
# Upney Underground Station - 940GZZLUUPY - district = None
# Upper Holloway Rail Station - 910GUPRHLWY - suffragette = None
# Upton Park Underground Station - 940GZZLUUPK - district = None
# Upton Park Underground Station - 940GZZLUUPK - hammersmith-city = None
# Uxbridge Underground Station - 940GZZLUUXB - metropolitan = None
# Uxbridge Underground Station - 940GZZLUUXB - piccadilly = None
# Vauxhall Underground Station - 940GZZLUVXL - victoria = HUBVXH
# Victoria Underground Station - 940GZZLUVIC - circle = HUBVIC
# Victoria Underground Station - 940GZZLUVIC - district = HUBVIC
# Victoria Underground Station - 940GZZLUVIC - victoria = HUBVIC
# Waddon Marsh - 940GZZCRWAD - tram = None
# Waddon Marsh - 940GZZCRWAD - tram = None
# Waddon Marsh Tram Stop - 940GZZCRWAD - tram = None
# Walthamstow Central Rail Station - 910GWLTWCEN - weaver = HUBWHC
# Walthamstow Central Underground Station - 940GZZLUWWL - victoria = HUBWHC
# Walthamstow Queens Road Rail Station - 910GWLTHQRD - suffragette = None
# Wandle Park - 940GZZCRWAN - tram = None
# Wandle Park - 940GZZCRWAN - tram = None
# Wandle Park Tram Stop - 940GZZCRWAN - tram = None
# Wandsworth Road Rail Station - 910GWNDSWRD - windrush = None
# Wanstead Park Rail Station - 910GWNSTDPK - suffragette = None
# Wanstead Underground Station - 940GZZLUWSD - central = None
# Wapping Rail Station - 910GWAPPING - windrush = None
# Warren Street Underground Station - 940GZZLUWRR - northern = None
# Warren Street Underground Station - 940GZZLUWRR - victoria = None
# Warwick Avenue Underground Station - 940GZZLUWKA - bakerloo = None
# Waterloo Underground Station - 940GZZLUWLO - bakerloo = HUBWAT
# Waterloo Underground Station - 940GZZLUWLO - jubilee = HUBWAT
# Waterloo Underground Station - 940GZZLUWLO - northern = HUBWAT
# Waterloo Underground Station - 940GZZLUWLO - waterloo-city = HUBWAT
# Watford High Street Rail Station - 910GWATFDHS - lioness = None
# Watford Junction Rail Station - 910GWATFJDC - lioness = HUBWFJ
# Watford Underground Station - 940GZZLUWAF - metropolitan = None
# Wellesley Road - 940GZZCRWEL - tram = None
# Wellesley Road Tram Stop - 940GZZCRWEL - tram = None
# Wembley Central Rail Station - 910GWMBY - lioness = HUBWMB
# Wembley Central Underground Station - 940GZZLUWYC - bakerloo = HUBWMB
# Wembley Park Underground Station - 940GZZLUWYP - jubilee = None
# Wembley Park Underground Station - 940GZZLUWYP - metropolitan = None
# West Acton Underground Station - 940GZZLUWTA - central = None
# West Brompton Rail Station - 910GWBRMPTN - mildmay = HUBWBP
# West Brompton Underground Station - 940GZZLUWBN - district = HUBWBP
# West Croydon - 940GZZCRWCR - tram = HUBWCY
# West Croydon Rail Station - 910GWCROYDN - windrush = HUBWCY
# West Croydon Tram Stop - 940GZZCRWCR - tram = HUBWCY
# West Drayton Rail Station - 910GWDRYTON - elizabeth = None
# West Ealing Rail Station - 910GWEALING - elizabeth = None
# West Finchley Underground Station - 940GZZLUWFN - northern = None
# West Ham DLR Station - 940GZZDLWHM - dlr = HUBWEH
# West Ham Underground Station - 940GZZLUWHM - district = HUBWEH
# West Ham Underground Station - 940GZZLUWHM - hammersmith-city = HUBWEH
# West Ham Underground Station - 940GZZLUWHM - jubilee = HUBWEH
# West Hampstead Rail Station - 910GWHMDSTD - mildmay = HUBWHD
# West Hampstead Underground Station - 940GZZLUWHP - jubilee = HUBWHD
# West Harrow Underground Station - 940GZZLUWHW - metropolitan = None
# West India Quay DLR Station - 940GZZDLWIQ - dlr = None
# West Kensington Underground Station - 940GZZLUWKN - district = None
# West Ruislip Underground Station - 940GZZLUWRP - central = HUBWRU
# West Silvertown DLR Station - 940GZZDLWSV - dlr = None
# Westbourne Park Underground Station - 940GZZLUWSP - circle = None
# Westbourne Park Underground Station - 940GZZLUWSP - hammersmith-city = None
# Westferry DLR Station - 940GZZDLWFE - dlr = None
# Westminster Underground Station - 940GZZLUWSM - circle = HUBWSM
# Westminster Underground Station - 940GZZLUWSM - district = HUBWSM
# Westminster Underground Station - 940GZZLUWSM - jubilee = HUBWSM
# White City Underground Station - 940GZZLUWCY - central = None
# White Hart Lane Rail Station - 910GWHHRTLA - weaver = None
# Whitechapel - 910GWCHAPXR - elizabeth = HUBZWL
# Whitechapel Rail Station - 910GWCHAPEL - windrush = HUBZWL
# Whitechapel Underground Station - 940GZZLUWPL - district = HUBZWL
# Whitechapel Underground Station - 940GZZLUWPL - hammersmith-city = HUBZWL
# Willesden Green Underground Station - 940GZZLUWIG - jubilee = None
# Willesden Junction Rail Station - 910GWLSDJHL - lioness = HUBWIJ
# Willesden Junction Rail Station - 910GWLSDJHL - mildmay = HUBWIJ
# Willesden Junction Underground Station - 940GZZLUWJN - bakerloo = HUBWIJ
# Wimbledon - 940GZZCRWMB - tram = HUBWIM
# Wimbledon Park Underground Station - 940GZZLUWIP - district = None
# Wimbledon Tram Stop - 940GZZCRWMB - tram = HUBWIM
# Wimbledon Underground Station - 940GZZLUWIM - district = HUBWIM
# Wood Green Underground Station - 940GZZLUWOG - piccadilly = None
# Wood Lane Underground Station - 940GZZLUWLA - circle = None
# Wood Lane Underground Station - 940GZZLUWLA - hammersmith-city = None
# Wood Street Rail Station - 910GWDST - weaver = None
# Woodford Underground Station - 940GZZLUWOF - central = None
# Woodgrange Park Rail Station - 910GWDGRNPK - suffragette = None
# Woodside - 940GZZCRWOD - tram = None
# Woodside - 940GZZCRWOD - tram = None
# Woodside Park Underground Station - 940GZZLUWOP - northern = None
# Woodside Tram Stop - 940GZZCRWOD - tram = None
# Woolwich - 910GWOLWXR - elizabeth = None
# Woolwich Arsenal DLR Station - 940GZZDLWLA - dlr = HUBWWA

# %%
id = "district"
direction = "outbound"
stops = fetch_tfl_data(f"/Line/{id}/Route/Sequence/{direction}")
#pprint(stops, depth=1, compact=True)
pprint(stops["stations"][-1], depth=3, compact=True)
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, '
#           'Tfl.Api.Presentation.Entities',
#  'icsId': '1000268',
#  'id': 'HUBZWL',
#  'lat': 51.519498,
#  'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': '205',
#             'name': '205',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/205'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': '25',
#             'name': '25',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/25'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': '254',
#             'name': '254',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/254'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'd3',
#             'name': 'D3',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/d3'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'district',
#             'name': 'District',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/district'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'elizabeth',
#             'name': 'Elizabeth line',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/elizabeth'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'hammersmith-city',
#             'name': 'Hammersmith & City',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/hammersmith-city'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'n205',
#             'name': 'N205',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/n205'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'n25',
#             'name': 'N25',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/n25'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'n253',
#             'name': 'N253',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/n253'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'windrush',
#             'name': 'Windrush',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/windrush'}],
#  'lon': -0.059858,
#  'modes': ['bus', 'elizabeth-line', 'overground', 'tube'],
#  'name': 'Whitechapel',
#  'status': True,
#  'stopType': 'TransportInterchange',
#  'zone': '2'}

# %%
route_stations = []

for station in stops["orderedLineRoutes"][0]["naptanIds"]: # Routes with variations have multiple  entries here
    print(f"{id}: {station}-{station_id[station]}")
    route_stations.append(f"{station}-{id}")
# Out:
# district: 940GZZLUEBY-Ealing Broadway Underground Station
# district: 940GZZLUECM-Ealing Common Underground Station
# district: 940GZZLUACT-Acton Town Underground Station
# district: 940GZZLUCWP-Chiswick Park Underground Station
# district: 940GZZLUTNG-Turnham Green Underground Station
# district: 940GZZLUSFB-Stamford Brook Underground Station
# district: 940GZZLURVP-Ravenscourt Park Underground Station
# district: 940GZZLUHSD-Hammersmith (Dist&Picc Line) Underground Station
# district: 940GZZLUBSC-Barons Court Underground Station
# district: 940GZZLUWKN-West Kensington Underground Station
# district: 940GZZLUECT-Earl's Court Underground Station
# district: 940GZZLUGTR-Gloucester Road Underground Station
# district: 940GZZLUSKS-South Kensington Underground Station
# district: 940GZZLUSSQ-Sloane Square Underground Station
# district: 940GZZLUVIC-Victoria Underground Station
# district: 940GZZLUSJP-St. James's Park Underground Station
# district: 940GZZLUWSM-Westminster Underground Station
# district: 940GZZLUEMB-Embankment Underground Station
# district: 940GZZLUTMP-Temple Underground Station
# district: 940GZZLUBKF-Blackfriars Underground Station
# district: 940GZZLUMSH-Mansion House Underground Station
# district: 940GZZLUCST-Cannon Street Underground Station
# district: 940GZZLUMMT-Monument Underground Station
# district: 940GZZLUTWH-Tower Hill Underground Station
# district: 940GZZLUADE-Aldgate East Underground Station
# district: 940GZZLUWPL-Whitechapel Underground Station
# district: 940GZZLUSGN-Stepney Green Underground Station
# district: 940GZZLUMED-Mile End Underground Station
# district: 940GZZLUBWR-Bow Road Underground Station
# district: 940GZZLUBBB-Bromley-by-Bow Underground Station
# district: 940GZZLUWHM-West Ham Underground Station
# district: 940GZZLUPLW-Plaistow Underground Station
# district: 940GZZLUUPK-Upton Park Underground Station
# district: 940GZZLUEHM-East Ham Underground Station
# district: 940GZZLUBKG-Barking Underground Station
# district: 940GZZLUUPY-Upney Underground Station
# district: 940GZZLUBEC-Becontree Underground Station
# district: 940GZZLUDGY-Dagenham Heathway Underground Station
# district: 940GZZLUDGE-Dagenham East Underground Station
# district: 940GZZLUEPK-Elm Park Underground Station
# district: 940GZZLUHCH-Hornchurch Underground Station
# district: 940GZZLUUPB-Upminster Bridge Underground Station
# district: 940GZZLUUPM-Upminster Underground Station

# %%
route_stations = []

for station in stops["orderedLineRoutes"][0]["naptanIds"]: # Routes with variations have multiple  entries here
    print(f"{id}: {station}-{station_id[station]}")
    route_stations.append(f"{station}-{id}")
# Out:
# windrush: 910GHGHI-Highbury & Islington Rail Station
# windrush: 910GCNNB-Canonbury Rail Station
# windrush: 910GDALS-Dalston Junction Rail Station
# windrush: 910GHAGGERS-Haggerston Rail Station
# windrush: 910GHOXTON-Hoxton Rail Station
# windrush: 910GSHRDHST-Shoreditch High Street Rail Station
# windrush: 910GWCHAPEL-Whitechapel Rail Station
# windrush: 910GSHADWEL-Shadwell Rail Station
# windrush: 910GWAPPING-Wapping Rail Station
# windrush: 910GRTHERHI-Rotherhithe Rail Station
# windrush: 910GCNDAW-Canada Water Rail Station
# windrush: 910GSURREYQ-Surrey Quays Rail Station
# windrush: 910GNWCRELL-New Cross ELL Rail Station

# %%
print(route_stations)
# Out:
# ['910GABWDXR-elizabeth', '910GWOLWXR-elizabeth', '910GCSTMHSXR-elizabeth', '910GCANWHRF-elizabeth', '910GWCHAPXR-elizabeth', '910GLIVSTLL-elizabeth', '910GFRNDXR-elizabeth', '910GTOTCTRD-elizabeth', '910GBONDST-elizabeth', '910GPADTLL-elizabeth', '910GACTONML-elizabeth', '910GEALINGB-elizabeth', '910GWEALING-elizabeth', '910GHANWELL-elizabeth', '910GSTHALL-elizabeth', '910GHAYESAH-elizabeth', '910GHTRWAPT-elizabeth', '910GHTRWTM4-elizabeth']

# %%
for x,y in zip(route_stations, route_stations[1:]):
    print(x, y)
# Out:
# 910GABWDXR-elizabeth 910GWOLWXR-elizabeth
# 910GWOLWXR-elizabeth 910GCSTMHSXR-elizabeth
# 910GCSTMHSXR-elizabeth 910GCANWHRF-elizabeth
# 910GCANWHRF-elizabeth 910GWCHAPXR-elizabeth
# 910GWCHAPXR-elizabeth 910GLIVSTLL-elizabeth
# 910GLIVSTLL-elizabeth 910GFRNDXR-elizabeth
# 910GFRNDXR-elizabeth 910GTOTCTRD-elizabeth
# 910GTOTCTRD-elizabeth 910GBONDST-elizabeth
# 910GBONDST-elizabeth 910GPADTLL-elizabeth
# 910GPADTLL-elizabeth 910GACTONML-elizabeth
# 910GACTONML-elizabeth 910GEALINGB-elizabeth
# 910GEALINGB-elizabeth 910GWEALING-elizabeth
# 910GWEALING-elizabeth 910GHANWELL-elizabeth
# 910GHANWELL-elizabeth 910GSTHALL-elizabeth
# 910GSTHALL-elizabeth 910GHAYESAH-elizabeth
# 910GHAYESAH-elizabeth 910GHTRWAPT-elizabeth
# 910GHTRWAPT-elizabeth 910GHTRWTM4-elizabeth

# %%
#pprint(stops, depth=1, compact=True)
pprint(stops["orderedLineRoutes"][0], depth=2, compact=True)
route_stops = stops["orderedLineRoutes"][0]["naptanIds"]
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.OrderedRoute, '
#           'Tfl.Api.Presentation.Entities',
#  'name': 'Abbey Wood &harr;  Heathrow Terminal 4 ',
#  'naptanIds': ['910GABWDXR', '910GWOLWXR', '910GCSTMHSXR', '910GCANWHRF',
#                '910GWCHAPXR', '910GLIVSTLL', '910GFRNDXR', '910GTOTCTRD',
#                '910GBONDST', '910GPADTLL', '910GACTONML', '910GEALINGB',
#                '910GWEALING', '910GHANWELL', '910GSTHALL', '910GHAYESAH',
#                '910GHTRWAPT', '910GHTRWTM4'],
#  'serviceType': 'Regular'}

# %%
id = "elizabeth"
fromStopPointId = "Whitechapel"
toStopPointId = "910GHTRWTM4"

timetable = fetch_tfl_data(f"/Line/{id}/Timetable/{fromStopPointId}/to/{toStopPointId}")
# Out:
# HTTP Error 400: {"$type":"Tfl.Api.Presentation.Entities.ApiError, Tfl.Api.Presentation.Entities","timestampUtc":"2025-03-21T22:03:08.9493123Z","exceptionType":"ApiArgumentException","httpStatusCode":400,"httpStatus":"BadRequest","relativeUri":"/Line/elizabeth/Timetable/Whitechapel/to/910GHTRWTM4?app_id=Halfway&app_key=21dbb2eeb688456e817278669ba2c9d4","message":"The following stop points are not recognised: Whitechapel"}

# %%
timetable = fetch_tfl_data(f"/Journey/JourneyResults/{fromStopPointId}/to/{toStopPointId}?useRealTimeLiveArrivals=false")
pprint(timetable, depth=2)
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.DisambiguationResult, '
#           'Tfl.Api.Presentation.Entities',
#  'fromLocationDisambiguation': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Disambiguation, '
#                                          'Tfl.Api.Presentation.Entities',
#                                 'disambiguationOptions': [...],
#                                 'matchStatus': 'list'},
#  'journeyVector': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.JourneyVector, '
#                             'Tfl.Api.Presentation.Entities',
#                    'from': 'Whitechapel',
#                    'to': '1000104',
#                    'uri': '/journey/journeyresults/whitechapel/to/910ghtrwtm4?userealtimelivearrivals=false&app_id=halfway&app_key=21dbb2eeb688456e817278669ba2c9d4',
#                    'via': ''},
#  'recommendedMaxAgeMinutes': 1440,
#  'searchCriteria': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.SearchCriteria, '
#                              'Tfl.Api.Presentation.Entities',
#                     'dateTime': '2025-03-21T22:03:00',
#                     'dateTimeType': 'Departing'},
#  'toLocationDisambiguation': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Disambiguation, '
#                                        'Tfl.Api.Presentation.Entities',
#                               'matchStatus': 'identified'},
#  'viaLocationDisambiguation': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Disambiguation, '
#                                         'Tfl.Api.Presentation.Entities',
#                                'matchStatus': 'empty'}}

# %%
id = "elizabeth"
from_ = "910GABWDXR"
to_ = "910GWOLWXR"

for from_, to_ in zip(route_stops, route_stops[1:]):
    timetable = fetch_tfl_data(f"/Journey/JourneyResults/{from_}/to/{to_}?useRealTimeLiveArrivals=false")
    durations = []
    for journey in timetable["journeys"]:
        durations.append(journey["duration"])
    print(f"{from_}->{to_}={min(durations)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       2 from_ = "HUBZWL"
#       3 to_ = "910GWOLWXR"
# ----> 5 for from_, to_ in zip(route_stops, route_stops[1:]):
#       6     timetable = fetch_tfl_data(f"/Journey/JourneyResults/{from_}/to/{to_}?useRealTimeLiveArrivals=false")
#       7     durations = []
#
# NameError: name 'route_stops' is not defined

# %%
id = "elizabeth"
from_ = "910GABWDXR"
to_ = "910GWOLWXR"

for from_, to_ in zip(route_stops, route_stops[1:]):
    timetable = fetch_tfl_data(f"/Journey/JourneyResults/{from_}/to/{to_}?useRealTimeLiveArrivals=false")
    durations = []
    for journey in timetable["journeys"]:
        durations.append(journey["duration"])
    print(f"{from_}->{to_}={min(durations)}")
# Out:
# 910GABWDXR->910GWOLWXR=3
# 910GWOLWXR->910GCSTMHSXR=4
# 910GCSTMHSXR->910GCANWHRF=4
# 910GCANWHRF->910GWCHAPXR=4
# 910GWCHAPXR->910GLIVSTLL=3
# 910GLIVSTLL->910GFRNDXR=2
# 910GFRNDXR->910GTOTCTRD=2
# 910GTOTCTRD->910GBONDST=2
# 910GBONDST->910GPADTLL=4
# 910GPADTLL->910GACTONML=6
# 910GACTONML->910GEALINGB=3
# 910GEALINGB->910GWEALING=2
# 910GWEALING->910GHANWELL=2
# 910GHANWELL->910GSTHALL=3
# 910GSTHALL->910GHAYESAH=3
# 910GHAYESAH->910GHTRWAPT=7
# 910GHTRWAPT->910GHTRWTM4=5

# %%
pprint(timetable, depth=3)
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.ItineraryResult, '
#           'Tfl.Api.Presentation.Entities',
#  'journeyVector': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.JourneyVector, '
#                             'Tfl.Api.Presentation.Entities',
#                    'from': '1001147',
#                    'to': '1000104',
#                    'uri': '/journey/journeyresults/910ghtrwapt/to/910ghtrwtm4?userealtimelivearrivals=false&app_id=halfway&app_key=21dbb2eeb688456e817278669ba2c9d4',
#                    'via': ''},
#  'journeys': [{'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, '
#                         'Tfl.Api.Presentation.Entities',
#                'alternativeRoute': False,
#                'arrivalDateTime': '2025-02-12T15:12:00',
#                'duration': 5,
#                'fare': {...},
#                'legs': [...],
#                'startDateTime': '2025-02-12T15:07:00'},
#               {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, '
#                         'Tfl.Api.Presentation.Entities',
#                'alternativeRoute': False,
#                'arrivalDateTime': '2025-02-12T15:27:00',
#                'duration': 5,
#                'fare': {...},
#                'legs': [...],
#                'startDateTime': '2025-02-12T15:22:00'},
#               {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, '
#                         'Tfl.Api.Presentation.Entities',
#                'alternativeRoute': False,
#                'arrivalDateTime': '2025-02-12T15:39:00',
#                'duration': 12,
#                'fare': {...},
#                'legs': [...],
#                'startDateTime': '2025-02-12T15:27:00'},
#               {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, '
#                         'Tfl.Api.Presentation.Entities',
#                'alternativeRoute': False,
#                'arrivalDateTime': '2025-02-12T15:51:00',
#                'duration': 47,
#                'legs': [...],
#                'startDateTime': '2025-02-12T15:04:00'}],
#  'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Line, '
#                      'Tfl.Api.Presentation.Entities',
#             'created': '2025-02-06T09:58:47.4Z',
#             'crowding': {...},
#             'disruptions': [],
#             'id': 'elizabeth',
#             'lineStatuses': [...],
#             'modeName': 'elizabeth-line',
#             'modified': '2025-02-06T09:58:47.4Z',
#             'name': 'Elizabeth line',
#             'routeSections': [],
#             'serviceTypes': [...]},
#            {'$type': 'Tfl.Api.Presentation.Entities.Line, '
#                      'Tfl.Api.Presentation.Entities',
#             'created': '2025-02-06T09:58:47.4Z',
#             'crowding': {...},
#             'disruptions': [],
#             'id': 'piccadilly',
#             'lineStatuses': [...],
#             'modeName': 'tube',
#             'modified': '2025-02-06T09:58:47.4Z',
#             'name': 'Piccadilly',
#             'routeSections': [],
#             'serviceTypes': [...]}],
#  'recommendedMaxAgeMinutes': 3,
#  'searchCriteria': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.SearchCriteria, '
#                              'Tfl.Api.Presentation.Entities',
#                     'dateTime': '2025-02-12T15:04:00',
#                     'dateTimeType': 'Departing',
#                     'timeAdjustments': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.TimeAdjustments, '
#                                                  'Tfl.Api.Presentation.Entities',
#                                         'earlier': {...},
#                                         'earliest': {...},
#                                         'later': {...},
#                                         'latest': {...}}},
#  'stopMessages': []}

# %%
pprint(timetable["timetable"]["routes"][0]["schedules"][0]) # periods/frequency
# https://api-portal.tfl.gov.uk/api-details#api=Line&operation=Line_TimetableByPathFromStopPointIdPathId
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pprint(timetable["timetable"]["routes"][0]["schedules"][0]) # periods/frequency
#       2 # https://api-portal.tfl.gov.uk/api-details#api=Line&operation=Line_TimetableByPathFromStopPointIdPathId
#
# KeyError: 'timetable'

# %%
pprint(timetable["timetable"]["routes"][0]["schedules"][0]["periods"][1]["frequency"]["highestFrequency"]) # periods/frequency
pprint(timetable["timetable"]["routes"][0]["schedules"][0]["periods"][1]["frequency"]["lowestFrequency"]) # periods/frequency

# https://api-portal.tfl.gov.uk/api-details#api=Line&operation=Line_TimetableByPathFromStopPointIdPathId

# %%
def time_from_journey(journey):
    return int(journey["hour"]) * 60 + int(journey["minute"])
    
first = timetable["timetable"]["routes"][0]["schedules"][0]["firstJourney"]
first_time = time_from_journey(first)
for schedule in timetable["timetable"]["routes"][0]["schedules"][0]["knownJourneys"][1:]:
    next_time = time_from_journey(schedule)
    print(f"Time between Trains = {next_time - first_time} mins")
    first_time = next_time

# %%
pprint(timetable["timetable"]["routes"][0]["stationIntervals"], depth=2)

# %%
for stop in timetable["timetable"]["routes"][0]["stationIntervals"][0]["intervals"]:
    name = station_id[stop["stopId"]]
    arrivalTime = stop["timeToArrival"]
    print(f"{name}: {arrivalTime}") # Why are there 2 for almost all stations?

# %%
for stop in timetable["timetable"]["routes"][0]["stationIntervals"][1]["intervals"]:
    name = station_id[stop["stopId"]]
    arrivalTime = stop["timeToArrival"]
    print(f"{name}: {arrivalTime}") # Why are there 2 for almost all stations?
