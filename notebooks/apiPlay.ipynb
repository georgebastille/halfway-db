# %%
# !uv pip install pandas
# Out:
# Using Python 3.13.2 environment at: /home/richie/halfway/db-builder/.venv
# Audited 1 package in 1ms

# %%
import requests
from pprint import pprint
import os
import pandas as pd



APP_ID = os.environ.get("TFL_APP_ID")
APP_KEY = os.environ.get("TFL_APP_KEY")
base_url = "https://api.tfl.gov.uk"


def fetch_tfl_data(endpoint, params=None):
    url = f"{base_url}{endpoint}"
    params = params or {}
    params.update({"app_id": APP_ID, "app_key": APP_KEY})

    try:
        response = requests.get(url, params=params, timeout=15)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.HTTPError as e:
        print(f"\nHTTP Error {response.status_code}: {response.text}")
        return None
    except Exception as e:
        print(f"\nError fetching {url}: {str(e)}")
        return None

# %% [markdown]
# # Constructing the TFL network as a Graph
# ### Steps
# 1. Decide on the list of transport modes you want and ensure they are supported
# 2. For each mode, get the list of lines (e.g. tube, victoria)
# 3. For each line, get the ordered list of stations that serve that line, name + id
# 4. For each station+line, construct a node_id and save these nodes
# 5. From the ordered list of stations, construct a set of same line edges, one station apart
# 6. For each station, append the lines it serves, and construct interstation edges
# 7. For the interline edges, query tfl for the times to get from each station to the next
# 8. For the interstation egdes, identify a method for determining the transition time (one idea, try a query for one station before and one after on each side, and subtract the known train times to that station.
# 9. Construct the graph with our nodes and edges
# 10. Run Dijkstra and get all node->node times
# 11. Collapse routes with multipe platforms to the minimum distance.
# 12. YUUU$$$

# %%
all_modes = fetch_tfl_data("/Line/Meta/Modes")
for mode in all_modes:
    print(mode["modeName"])
# Out:
# bus
# cable-car
# coach
# cycle
# cycle-hire
# dlr
# elizabeth-line
# interchange-keep-sitting
# interchange-secure
# national-rail
# overground
# replacement-bus
# river-bus
# river-tour
# taxi
# tram
# tube
# walking

# %%
modes = ["tube", "overground", "dlr", "elizabeth-line", "tram"]
lines = fetch_tfl_data("/Line/Mode/" + ",".join(modes))

# %%
line_ids = []
lines_ld = []
for line in lines:
    #print(line["id"], line["name"], line["modeName"])
    line_ids.append(line["id"])
    line_d = {}
    line_d["line_name"] = line["name"]
    line_d["line_id"] = line["id"]
    lines_ld.append(line_d)

df = pd.DataFrame(lines_ld)
print(df)
# Out:
#              line_name           line_id
# 0             Bakerloo          bakerloo
# 1              Central           central
# 2               Circle            circle
# 3             District          district
# 4                  DLR               dlr
# 5       Elizabeth line         elizabeth
# 6   Hammersmith & City  hammersmith-city
# 7              Jubilee           jubilee
# 8              Liberty           liberty
# 9              Lioness           lioness
# 10        Metropolitan      metropolitan
# 11             Mildmay           mildmay
# 12            Northern          northern
# 13          Piccadilly        piccadilly
# 14         Suffragette       suffragette
# 15                Tram              tram
# 16            Victoria          victoria
# 17     Waterloo & City     waterloo-city
# 18              Weaver            weaver
# 19            Windrush          windrush

# %%
id = "HUBEPH"
stops = fetch_tfl_data(f"/StopPoint/940GZZLUBST,{id},940GZZLULGT")
pprint(stops, depth=2)
#pprint(stops["children"], depth=2)
#for x in stops["children"]:
#    print(x["commonName"], x["naptanId"], x["stationNaptan"])
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPoint, '
#            'Tfl.Api.Presentation.Entities',
#   'additionalProperties': [...],
#   'children': [...],
#   'commonName': 'Baker Street Underground Station',
#   'icsCode': '1000011',
#   'id': '940GZZLUBST',
#   'lat': 51.522883,
#   'lineGroup': [...],
#   'lineModeGroups': [...],
#   'lines': [...],
#   'lon': -0.15713,
#   'modes': [...],
#   'naptanId': '940GZZLUBST',
#   'placeType': 'StopPoint',
#   'stationNaptan': '940GZZLUBST',
#   'status': True,
#   'stopType': 'NaptanMetroStation'},
#  {'$type': 'Tfl.Api.Presentation.Entities.StopPoint, '
#            'Tfl.Api.Presentation.Entities',
#   'additionalProperties': [...],
#   'children': [...],
#   'commonName': 'Lancaster Gate Underground Station',
#   'icsCode': '1000133',
#   'id': '940GZZLULGT',
#   'lat': 51.511723,
#   'lineGroup': [...],
#   'lineModeGroups': [...],
#   'lines': [...],
#   'lon': -0.175494,
#   'modes': [...],
#   'naptanId': '940GZZLULGT',
#   'placeType': 'StopPoint',
#   'stationNaptan': '940GZZLULGT',
#   'status': True,
#   'stopType': 'NaptanMetroStation'},
#  {'$type': 'Tfl.Api.Presentation.Entities.StopPoint, '
#            'Tfl.Api.Presentation.Entities',
#   'additionalProperties': [...],
#   'children': [...],
#   'commonName': 'Elephant & Castle',
#   'hubNaptanCode': 'HUBEPH',
#   'icsCode': '1000073',
#   'id': 'HUBEPH',
#   'lat': 51.494505,
#   'lineGroup': [...],
#   'lineModeGroups': [...],
#   'lines': [...],
#   'lon': -0.099185,
#   'modes': [...],
#   'naptanId': 'HUBEPH',
#   'placeType': 'StopPoint',
#   'status': True,
#   'stopType': 'TransportInterchange'}]

# %%
station_id = {}
station_dict = []
hubs = []
strs = []

for line_id in line_ids:
    stops = fetch_tfl_data(f"/Line/{line_id}/StopPoints?tflOperatedNationalRailStationsOnly=false")
    #print(stops[0].keys())
    #pprint(stops, depth=2, compact=True)
    #print("\n\n")
    #pprint(stops[0]["children"])
    for stop in stops:
        name = stop["commonName"]
        naptanId = stop["stationNaptan"]
        hub_name = name
        if hub := stop.get("hubNaptanCode", None):
            hubs.append(hub)
            hub_name = None
        print(line_id, name, naptanId, hub, hub_name)

        
        #pprint(stop, depth=2)
        #for x in stop["children"]:
        #    print(line_id, x["commonName"], x["naptanId"], x["stationNaptan"], hub)

        #print(f"{naptanId}: {name} - {line_id} - {hub}")
        strs.append(f"{name} - {naptanId} - {line_id} = {hub}")
        station_id[naptanId] = name
        station = {}
        station["station_id"] = naptanId
        station["station_name"] = name
        station["station_line"] = line_id
        station_dict.append(station)
df = pd.DataFrame(station_dict)
strs = sorted(strs)
for s in strs:
    print(s)
#print(hubs)
#df.head()
# Out:
# bakerloo Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station
# bakerloo Charing Cross Underground Station 940GZZLUCHX HUBCHX None
# bakerloo Elephant & Castle Underground Station 940GZZLUEAC HUBEPH None
# bakerloo Embankment Underground Station 940GZZLUEMB None Embankment Underground Station
# bakerloo Edgware Road (Bakerloo) Underground Station 940GZZLUERB None Edgware Road (Bakerloo) Underground Station
# bakerloo Harrow & Wealdstone Underground Station 940GZZLUHAW HUBHRW None
# bakerloo Harlesden Underground Station 940GZZLUHSN HUBHDN None
# bakerloo Kenton Underground Station 940GZZLUKEN HUBKNT None
# bakerloo Kilburn Park Underground Station 940GZZLUKPK None Kilburn Park Underground Station
# bakerloo Kensal Green Underground Station 940GZZLUKSL HUBKNL None
# bakerloo Lambeth North Underground Station 940GZZLULBN None Lambeth North Underground Station
# bakerloo Maida Vale Underground Station 940GZZLUMVL None Maida Vale Underground Station
# bakerloo Marylebone Underground Station 940GZZLUMYB HUBMYB None
# bakerloo North Wembley Underground Station 940GZZLUNWY HUBNWB None
# bakerloo Oxford Circus Underground Station 940GZZLUOXC None Oxford Circus Underground Station
# bakerloo Paddington Underground Station 940GZZLUPAC HUBPAD None
# bakerloo Piccadilly Circus Underground Station 940GZZLUPCC None Piccadilly Circus Underground Station
# bakerloo Queen's Park Underground Station 940GZZLUQPS HUBQPW None
# bakerloo Regent's Park Underground Station 940GZZLURGP None Regent's Park Underground Station
# bakerloo Stonebridge Park Underground Station 940GZZLUSGP HUBSBP None
# bakerloo South Kenton Underground Station 940GZZLUSKT HUBSOK None
# bakerloo Willesden Junction Underground Station 940GZZLUWJN HUBWIJ None
# bakerloo Warwick Avenue Underground Station 940GZZLUWKA None Warwick Avenue Underground Station
# bakerloo Waterloo Underground Station 940GZZLUWLO HUBWAT None
# bakerloo Wembley Central Underground Station 940GZZLUWYC HUBWMB None
# central Barkingside Underground Station 940GZZLUBKE None Barkingside Underground Station
# central Buckhurst Hill Underground Station 940GZZLUBKH None Buckhurst Hill Underground Station
# central Bethnal Green Underground Station 940GZZLUBLG None Bethnal Green Underground Station
# central Bond Street Underground Station 940GZZLUBND HUBBDS None
# central Bank Underground Station 940GZZLUBNK HUBBAN None
# central Chancery Lane Underground Station 940GZZLUCHL None Chancery Lane Underground Station
# central Chigwell Underground Station 940GZZLUCWL None Chigwell Underground Station
# central Debden Underground Station 940GZZLUDBN None Debden Underground Station
# central East Acton Underground Station 940GZZLUEAN None East Acton Underground Station
# central Ealing Broadway Underground Station 940GZZLUEBY HUBEAL None
# central Epping Underground Station 940GZZLUEPG None Epping Underground Station
# central Fairlop Underground Station 940GZZLUFLP None Fairlop Underground Station
# central Greenford Underground Station 940GZZLUGFD HUBGFD None
# central Grange Hill Underground Station 940GZZLUGGH None Grange Hill Underground Station
# central Gants Hill Underground Station 940GZZLUGTH None Gants Hill Underground Station
# central Holborn Underground Station 940GZZLUHBN None Holborn Underground Station
# central Hanger Lane Underground Station 940GZZLUHGR None Hanger Lane Underground Station
# central Hainault Underground Station 940GZZLUHLT None Hainault Underground Station
# central Holland Park Underground Station 940GZZLUHPK None Holland Park Underground Station
# central Loughton Underground Station 940GZZLULGN None Loughton Underground Station
# central Lancaster Gate Underground Station 940GZZLULGT None Lancaster Gate Underground Station
# central Liverpool Street Underground Station 940GZZLULVT HUBLST None
# central Leyton Underground Station 940GZZLULYN None Leyton Underground Station
# central Leytonstone Underground Station 940GZZLULYS None Leytonstone Underground Station
# central Marble Arch Underground Station 940GZZLUMBA None Marble Arch Underground Station
# central Mile End Underground Station 940GZZLUMED None Mile End Underground Station
# central North Acton Underground Station 940GZZLUNAN None North Acton Underground Station
# central Newbury Park Underground Station 940GZZLUNBP None Newbury Park Underground Station
# central Notting Hill Gate Underground Station 940GZZLUNHG None Notting Hill Gate Underground Station
# central Northolt Underground Station 940GZZLUNHT None Northolt Underground Station
# central Oxford Circus Underground Station 940GZZLUOXC None Oxford Circus Underground Station
# central Perivale Underground Station 940GZZLUPVL None Perivale Underground Station
# central Queensway Underground Station 940GZZLUQWY None Queensway Underground Station
# central Redbridge Underground Station 940GZZLURBG None Redbridge Underground Station
# central Ruislip Gardens Underground Station 940GZZLURSG None Ruislip Gardens Underground Station
# central Roding Valley Underground Station 940GZZLURVY None Roding Valley Underground Station
# central Shepherd's Bush (Central) Underground Station 940GZZLUSBC HUBSPB None
# central Snaresbrook Underground Station 940GZZLUSNB None Snaresbrook Underground Station
# central St. Paul's Underground Station 940GZZLUSPU None St. Paul's Underground Station
# central South Ruislip Underground Station 940GZZLUSRP HUBSRU None
# central Stratford Underground Station 940GZZLUSTD HUBSRA None
# central South Woodford Underground Station 940GZZLUSWF None South Woodford Underground Station
# central Tottenham Court Road Underground Station 940GZZLUTCR HUBTCR None
# central Theydon Bois Underground Station 940GZZLUTHB None Theydon Bois Underground Station
# central White City Underground Station 940GZZLUWCY None White City Underground Station
# central Woodford Underground Station 940GZZLUWOF None Woodford Underground Station
# central West Ruislip Underground Station 940GZZLUWRP HUBWRU None
# central Wanstead Underground Station 940GZZLUWSD None Wanstead Underground Station
# central West Acton Underground Station 940GZZLUWTA None West Acton Underground Station
# circle Aldgate Underground Station 940GZZLUALD None Aldgate Underground Station
# circle Barbican Underground Station 940GZZLUBBN None Barbican Underground Station
# circle Blackfriars Underground Station 940GZZLUBKF HUBBFR None
# circle Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station
# circle Bayswater Underground Station 940GZZLUBWT None Bayswater Underground Station
# circle Cannon Street Underground Station 940GZZLUCST HUBCST None
# circle Embankment Underground Station 940GZZLUEMB None Embankment Underground Station
# circle Edgware Road (Circle Line) Underground Station 940GZZLUERC None Edgware Road (Circle Line) Underground Station
# circle Euston Square Underground Station 940GZZLUESQ None Euston Square Underground Station
# circle Farringdon Underground Station 940GZZLUFCN HUBZFD None
# circle Goldhawk Road Underground Station 940GZZLUGHK None Goldhawk Road Underground Station
# circle Great Portland Street Underground Station 940GZZLUGPS None Great Portland Street Underground Station
# circle Gloucester Road Underground Station 940GZZLUGTR None Gloucester Road Underground Station
# circle Hammersmith (H&C Line) Underground Station 940GZZLUHSC HUBHMS None
# circle High Street Kensington Underground Station 940GZZLUHSK None High Street Kensington Underground Station
# circle King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None
# circle Ladbroke Grove Underground Station 940GZZLULAD None Ladbroke Grove Underground Station
# circle Latimer Road Underground Station 940GZZLULRD None Latimer Road Underground Station
# circle Liverpool Street Underground Station 940GZZLULVT HUBLST None
# circle Moorgate Underground Station 940GZZLUMGT HUBZMG None
# circle Monument Underground Station 940GZZLUMMT None Monument Underground Station
# circle Mansion House Underground Station 940GZZLUMSH None Mansion House Underground Station
# circle Notting Hill Gate Underground Station 940GZZLUNHG None Notting Hill Gate Underground Station
# circle Paddington Underground Station 940GZZLUPAC HUBPAD None
# circle Paddington (H&C Line)-Underground 940GZZLUPAH HUBPAD None
# circle Royal Oak Underground Station 940GZZLURYO None Royal Oak Underground Station
# circle Shepherd's Bush Market Underground Station 940GZZLUSBM None Shepherd's Bush Market Underground Station
# circle St. James's Park Underground Station 940GZZLUSJP None St. James's Park Underground Station
# circle South Kensington Underground Station 940GZZLUSKS None South Kensington Underground Station
# circle Sloane Square Underground Station 940GZZLUSSQ None Sloane Square Underground Station
# circle Temple Underground Station 940GZZLUTMP None Temple Underground Station
# circle Tower Hill Underground Station 940GZZLUTWH None Tower Hill Underground Station
# circle Victoria Underground Station 940GZZLUVIC HUBVIC None
# circle Wood Lane Underground Station 940GZZLUWLA None Wood Lane Underground Station
# circle Westminster Underground Station 940GZZLUWSM HUBWSM None
# circle Westbourne Park Underground Station 940GZZLUWSP None Westbourne Park Underground Station
# district Acton Town Underground Station 940GZZLUACT None Acton Town Underground Station
# district Aldgate East Underground Station 940GZZLUADE None Aldgate East Underground Station
# district Bromley-by-Bow Underground Station 940GZZLUBBB None Bromley-by-Bow Underground Station
# district Becontree Underground Station 940GZZLUBEC None Becontree Underground Station
# district Blackfriars Underground Station 940GZZLUBKF HUBBFR None
# district Barking Underground Station 940GZZLUBKG HUBBKG None
# district Barons Court Underground Station 940GZZLUBSC None Barons Court Underground Station
# district Bow Road Underground Station 940GZZLUBWR None Bow Road Underground Station
# district Bayswater Underground Station 940GZZLUBWT None Bayswater Underground Station
# district Cannon Street Underground Station 940GZZLUCST HUBCST None
# district Chiswick Park Underground Station 940GZZLUCWP None Chiswick Park Underground Station
# district Dagenham East Underground Station 940GZZLUDGE None Dagenham East Underground Station
# district Dagenham Heathway Underground Station 940GZZLUDGY None Dagenham Heathway Underground Station
# district Ealing Broadway Underground Station 940GZZLUEBY HUBEAL None
# district Ealing Common Underground Station 940GZZLUECM None Ealing Common Underground Station
# district Earl's Court Underground Station 940GZZLUECT None Earl's Court Underground Station
# district East Ham Underground Station 940GZZLUEHM None East Ham Underground Station
# district Embankment Underground Station 940GZZLUEMB None Embankment Underground Station
# district Elm Park Underground Station 940GZZLUEPK None Elm Park Underground Station
# district East Putney Underground Station 940GZZLUEPY None East Putney Underground Station
# district Edgware Road (Circle Line) Underground Station 940GZZLUERC None Edgware Road (Circle Line) Underground Station
# district Fulham Broadway Underground Station 940GZZLUFBY None Fulham Broadway Underground Station
# district Gunnersbury Underground Station 940GZZLUGBY HUBGUN None
# district Gloucester Road Underground Station 940GZZLUGTR None Gloucester Road Underground Station
# district Hornchurch Underground Station 940GZZLUHCH None Hornchurch Underground Station
# district Hammersmith (Dist&Picc Line) Underground Station 940GZZLUHSD HUBHMS None
# district High Street Kensington Underground Station 940GZZLUHSK None High Street Kensington Underground Station
# district Kensington (Olympia) Underground Station 940GZZLUKOY HUBKPA None
# district Kew Gardens Underground Station 940GZZLUKWG HUBKWG None
# district Mile End Underground Station 940GZZLUMED None Mile End Underground Station
# district Monument Underground Station 940GZZLUMMT None Monument Underground Station
# district Mansion House Underground Station 940GZZLUMSH None Mansion House Underground Station
# district Notting Hill Gate Underground Station 940GZZLUNHG None Notting Hill Gate Underground Station
# district Paddington Underground Station 940GZZLUPAC HUBPAD None
# district Plaistow Underground Station 940GZZLUPLW None Plaistow Underground Station
# district Parsons Green Underground Station 940GZZLUPSG None Parsons Green Underground Station
# district Putney Bridge Underground Station 940GZZLUPYB None Putney Bridge Underground Station
# district Richmond Underground Station 940GZZLURMD HUBRMD None
# district Ravenscourt Park Underground Station 940GZZLURVP None Ravenscourt Park Underground Station
# district Stamford Brook Underground Station 940GZZLUSFB None Stamford Brook Underground Station
# district Southfields Underground Station 940GZZLUSFS None Southfields Underground Station
# district Stepney Green Underground Station 940GZZLUSGN None Stepney Green Underground Station
# district St. James's Park Underground Station 940GZZLUSJP None St. James's Park Underground Station
# district South Kensington Underground Station 940GZZLUSKS None South Kensington Underground Station
# district Sloane Square Underground Station 940GZZLUSSQ None Sloane Square Underground Station
# district Temple Underground Station 940GZZLUTMP None Temple Underground Station
# district Turnham Green Underground Station 940GZZLUTNG None Turnham Green Underground Station
# district Tower Hill Underground Station 940GZZLUTWH None Tower Hill Underground Station
# district Upminster Bridge Underground Station 940GZZLUUPB None Upminster Bridge Underground Station
# district Upton Park Underground Station 940GZZLUUPK None Upton Park Underground Station
# district Upminster Underground Station 940GZZLUUPM HUBUPM None
# district Upney Underground Station 940GZZLUUPY None Upney Underground Station
# district Victoria Underground Station 940GZZLUVIC HUBVIC None
# district West Brompton Underground Station 940GZZLUWBN HUBWBP None
# district West Ham Underground Station 940GZZLUWHM HUBWEH None
# district Wimbledon Underground Station 940GZZLUWIM HUBWIM None
# district Wimbledon Park Underground Station 940GZZLUWIP None Wimbledon Park Underground Station
# district West Kensington Underground Station 940GZZLUWKN None West Kensington Underground Station
# district Whitechapel Underground Station 940GZZLUWPL HUBZWL None
# district Westminster Underground Station 940GZZLUWSM HUBWSM None
# dlr Abbey Road DLR Station 940GZZDLABR None Abbey Road DLR Station
# dlr All Saints DLR Station 940GZZDLALL None All Saints DLR Station
# dlr Beckton DLR Station 940GZZDLBEC None Beckton DLR Station
# dlr Blackwall DLR Station 940GZZDLBLA None Blackwall DLR Station
# dlr Bank DLR Station 940GZZDLBNK HUBBAN None
# dlr Bow Church DLR Station 940GZZDLBOW None Bow Church DLR Station
# dlr Beckton Park DLR Station 940GZZDLBPK None Beckton Park DLR Station
# dlr Canary Wharf DLR Station 940GZZDLCAN HUBCAW None
# dlr Canning Town DLR Station 940GZZDLCGT HUBCAN None
# dlr Crossharbour DLR Station 940GZZDLCLA None Crossharbour DLR Station
# dlr Custom House (for ExCel) DLR Station 940GZZDLCUS HUBCUS None
# dlr Cutty Sark (for Maritime Greenwich) DLR Station 940GZZDLCUT HUBCUT None
# dlr Cyprus DLR Station 940GZZDLCYP None Cyprus DLR Station
# dlr Deptford Bridge DLR Station 940GZZDLDEP None Deptford Bridge DLR Station
# dlr Devons Road DLR Station 940GZZDLDEV None Devons Road DLR Station
# dlr East India DLR Station 940GZZDLEIN None East India DLR Station
# dlr Elverson Road DLR Station 940GZZDLELV None Elverson Road DLR Station
# dlr Gallions Reach DLR Station 940GZZDLGAL None Gallions Reach DLR Station
# dlr Greenwich DLR Station 940GZZDLGRE HUBGNW None
# dlr Heron Quays DLR Station 940GZZDLHEQ None Heron Quays DLR Station
# dlr Island Gardens DLR Station 940GZZDLISL None Island Gardens DLR Station
# dlr King George V DLR Station 940GZZDLKGV None King George V DLR Station
# dlr London City Airport DLR Station 940GZZDLLCA HUBLCY None
# dlr Langdon Park DLR Station 940GZZDLLDP None Langdon Park DLR Station
# dlr Lewisham DLR Station 940GZZDLLEW HUBLEW None
# dlr Limehouse DLR Station 940GZZDLLIM HUBLHS None
# dlr Mudchute DLR Station 940GZZDLMUD None Mudchute DLR Station
# dlr Pontoon Dock DLR Station 940GZZDLPDK None Pontoon Dock DLR Station
# dlr Poplar DLR Station 940GZZDLPOP None Poplar DLR Station
# dlr Prince Regent DLR Station 940GZZDLPRE None Prince Regent DLR Station
# dlr Pudding Mill Lane DLR Station 940GZZDLPUD None Pudding Mill Lane DLR Station
# dlr Royal Albert DLR Station 940GZZDLRAL None Royal Albert DLR Station
# dlr Royal Victoria DLR Station 940GZZDLRVC HUBRVC None
# dlr Shadwell DLR Station 940GZZDLSHA HUBSDE None
# dlr Stratford High Street DLR Station 940GZZDLSHS None Stratford High Street DLR Station
# dlr Stratford International DLR Station 940GZZDLSIT None Stratford International DLR Station
# dlr South Quay DLR Station 940GZZDLSOQ None South Quay DLR Station
# dlr Stratford DLR Station 940GZZDLSTD HUBSRA None
# dlr Star Lane DLR Station 940GZZDLSTL None Star Lane DLR Station
# dlr Tower Gateway DLR Station 940GZZDLTWG HUBTOG None
# dlr Westferry DLR Station 940GZZDLWFE None Westferry DLR Station
# dlr West Ham DLR Station 940GZZDLWHM HUBWEH None
# dlr West India Quay DLR Station 940GZZDLWIQ None West India Quay DLR Station
# dlr Woolwich Arsenal DLR Station 940GZZDLWLA HUBWWA None
# dlr West Silvertown DLR Station 940GZZDLWSV None West Silvertown DLR Station
# elizabeth Abbey Wood 910GABWDXR HUBABW None
# elizabeth Acton Main Line Rail Station 910GACTONML None Acton Main Line Rail Station
# elizabeth Burnham (Berks) Rail Station 910GBNHAM None Burnham (Berks) Rail Station
# elizabeth Bond Street 910GBONDST HUBBDS None
# elizabeth Brentwood Rail Station 910GBRTWOOD None Brentwood Rail Station
# elizabeth Canary Wharf 910GCANWHRF HUBCAW None
# elizabeth Chadwell Heath Rail Station 910GCHDWLHT None Chadwell Heath Rail Station
# elizabeth Custom House 910GCSTMHSXR HUBCUS None
# elizabeth Ealing Broadway Rail Station 910GEALINGB HUBEAL None
# elizabeth Farringdon 910GFRNDXR HUBZFD None
# elizabeth Forest Gate Rail Station 910GFRSTGT None Forest Gate Rail Station
# elizabeth Gidea Park Rail Station 910GGIDEAPK None Gidea Park Rail Station
# elizabeth Goodmayes Rail Station 910GGODMAYS None Goodmayes Rail Station
# elizabeth Hanwell Rail Station 910GHANWELL None Hanwell Rail Station
# elizabeth Hayes & Harlington Rail Station 910GHAYESAH None Hayes & Harlington Rail Station
# elizabeth Harold Wood Rail Station 910GHRLDWOD None Harold Wood Rail Station
# elizabeth Heathrow Terminals 2 & 3 Rail Station 910GHTRWAPT HUBH13 None
# elizabeth Heathrow Terminal 4 Rail Station 910GHTRWTM4 HUBHX4 None
# elizabeth Heathrow Terminal 5 Rail Station 910GHTRWTM5 HUBHX5 None
# elizabeth Ilford Rail Station 910GILFORD None Ilford Rail Station
# elizabeth Iver Rail Station 910GIVER None Iver Rail Station
# elizabeth Langley (Berks) Rail Station 910GLANGLEY None Langley (Berks) Rail Station
# elizabeth London Liverpool Street Rail Station 910GLIVST HUBLST None
# elizabeth Liverpool Street 910GLIVSTLL HUBLST None
# elizabeth Manor Park Rail Station 910GMANRPK None Manor Park Rail Station
# elizabeth Maidenhead Rail Station 910GMDNHEAD None Maidenhead Rail Station
# elizabeth Maryland Rail Station 910GMRYLAND None Maryland Rail Station
# elizabeth Paddington 910GPADTLL HUBPAD None
# elizabeth London Paddington Rail Station 910GPADTON HUBPAD None
# elizabeth Reading Rail Station 910GRDNGSTN None Reading Rail Station
# elizabeth Romford Rail Station 910GROMFORD None Romford Rail Station
# elizabeth Shenfield Rail Station 910GSHENFLD None Shenfield Rail Station
# elizabeth Slough Rail Station 910GSLOUGH None Slough Rail Station
# elizabeth Stratford (London) Rail Station 910GSTFD HUBSRA None
# elizabeth Southall Rail Station 910GSTHALL None Southall Rail Station
# elizabeth Seven Kings Rail Station 910GSVNKNGS None Seven Kings Rail Station
# elizabeth Taplow Rail Station 910GTAPLOW None Taplow Rail Station
# elizabeth Tottenham Court Road 910GTOTCTRD HUBTCR None
# elizabeth Twyford Rail Station 910GTWYFORD None Twyford Rail Station
# elizabeth Whitechapel 910GWCHAPXR HUBZWL None
# elizabeth West Drayton Rail Station 910GWDRYTON None West Drayton Rail Station
# elizabeth West Ealing Rail Station 910GWEALING None West Ealing Rail Station
# elizabeth Woolwich 910GWOLWXR None Woolwich
# hammersmith-city Aldgate East Underground Station 940GZZLUADE None Aldgate East Underground Station
# hammersmith-city Bromley-by-Bow Underground Station 940GZZLUBBB None Bromley-by-Bow Underground Station
# hammersmith-city Barbican Underground Station 940GZZLUBBN None Barbican Underground Station
# hammersmith-city Barking Underground Station 940GZZLUBKG HUBBKG None
# hammersmith-city Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station
# hammersmith-city Bow Road Underground Station 940GZZLUBWR None Bow Road Underground Station
# hammersmith-city East Ham Underground Station 940GZZLUEHM None East Ham Underground Station
# hammersmith-city Edgware Road (Circle Line) Underground Station 940GZZLUERC None Edgware Road (Circle Line) Underground Station
# hammersmith-city Euston Square Underground Station 940GZZLUESQ None Euston Square Underground Station
# hammersmith-city Farringdon Underground Station 940GZZLUFCN HUBZFD None
# hammersmith-city Goldhawk Road Underground Station 940GZZLUGHK None Goldhawk Road Underground Station
# hammersmith-city Great Portland Street Underground Station 940GZZLUGPS None Great Portland Street Underground Station
# hammersmith-city Hammersmith (H&C Line) Underground Station 940GZZLUHSC HUBHMS None
# hammersmith-city King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None
# hammersmith-city Ladbroke Grove Underground Station 940GZZLULAD None Ladbroke Grove Underground Station
# hammersmith-city Latimer Road Underground Station 940GZZLULRD None Latimer Road Underground Station
# hammersmith-city Liverpool Street Underground Station 940GZZLULVT HUBLST None
# hammersmith-city Mile End Underground Station 940GZZLUMED None Mile End Underground Station
# hammersmith-city Moorgate Underground Station 940GZZLUMGT HUBZMG None
# hammersmith-city Paddington (H&C Line)-Underground 940GZZLUPAH HUBPAD None
# hammersmith-city Plaistow Underground Station 940GZZLUPLW None Plaistow Underground Station
# hammersmith-city Royal Oak Underground Station 940GZZLURYO None Royal Oak Underground Station
# hammersmith-city Shepherd's Bush Market Underground Station 940GZZLUSBM None Shepherd's Bush Market Underground Station
# hammersmith-city Stepney Green Underground Station 940GZZLUSGN None Stepney Green Underground Station
# hammersmith-city Upton Park Underground Station 940GZZLUUPK None Upton Park Underground Station
# hammersmith-city West Ham Underground Station 940GZZLUWHM HUBWEH None
# hammersmith-city Wood Lane Underground Station 940GZZLUWLA None Wood Lane Underground Station
# hammersmith-city Whitechapel Underground Station 940GZZLUWPL HUBZWL None
# hammersmith-city Westbourne Park Underground Station 940GZZLUWSP None Westbourne Park Underground Station
# jubilee Bermondsey Underground Station 940GZZLUBMY None Bermondsey Underground Station
# jubilee Bond Street Underground Station 940GZZLUBND HUBBDS None
# jubilee Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station
# jubilee Canning Town Underground Station 940GZZLUCGT HUBCAN None
# jubilee Canons Park Underground Station 940GZZLUCPK None Canons Park Underground Station
# jubilee Canada Water Underground Station 940GZZLUCWR HUBZCW None
# jubilee Canary Wharf Underground Station 940GZZLUCYF HUBCAW None
# jubilee Dollis Hill Underground Station 940GZZLUDOH None Dollis Hill Underground Station
# jubilee Finchley Road Underground Station 940GZZLUFYR None Finchley Road Underground Station
# jubilee Green Park Underground Station 940GZZLUGPK None Green Park Underground Station
# jubilee Kilburn Underground Station 940GZZLUKBN None Kilburn Underground Station
# jubilee Kingsbury Underground Station 940GZZLUKBY None Kingsbury Underground Station
# jubilee London Bridge Underground Station 940GZZLULNB HUBLBG None
# jubilee Neasden Underground Station 940GZZLUNDN None Neasden Underground Station
# jubilee North Greenwich Underground Station 940GZZLUNGW HUBNGW None
# jubilee Queensbury Underground Station 940GZZLUQBY None Queensbury Underground Station
# jubilee St. John's Wood Underground Station 940GZZLUSJW None St. John's Wood Underground Station
# jubilee Stratford Underground Station 940GZZLUSTD HUBSRA None
# jubilee Stanmore Underground Station 940GZZLUSTM None Stanmore Underground Station
# jubilee Swiss Cottage Underground Station 940GZZLUSWC None Swiss Cottage Underground Station
# jubilee Southwark Underground Station 940GZZLUSWK None Southwark Underground Station
# jubilee West Ham Underground Station 940GZZLUWHM HUBWEH None
# jubilee West Hampstead Underground Station 940GZZLUWHP HUBWHD None
# jubilee Willesden Green Underground Station 940GZZLUWIG None Willesden Green Underground Station
# jubilee Waterloo Underground Station 940GZZLUWLO HUBWAT None
# jubilee Westminster Underground Station 940GZZLUWSM HUBWSM None
# jubilee Wembley Park Underground Station 940GZZLUWYP None Wembley Park Underground Station
# liberty Emerson Park Rail Station 910GEMRSPKH None Emerson Park Rail Station
# liberty Romford Rail Station 910GROMFORD None Romford Rail Station
# liberty Upminster Rail Station 910GUPMNSTR HUBUPM None
# lioness Bushey Rail Station 910GBUSHYDC HUBBSH None
# lioness Carpenders Park Rail Station 910GCRPNDPK None Carpenders Park Rail Station
# lioness London Euston Rail Station 910GEUSTON HUBEUS None
# lioness Harlesden Rail Station 910GHARLSDN HUBHDN None
# lioness Headstone Lane Rail Station 910GHEDSTNL None Headstone Lane Rail Station
# lioness Harrow & Wealdstone Rail Station 910GHROW HUBHRW None
# lioness Hatch End Rail Station 910GHTCHEND None Hatch End Rail Station
# lioness Kensal Green Rail Station 910GKENSLG HUBKNL None
# lioness Kilburn High Road Rail Station 910GKLBRNHR None Kilburn High Road Rail Station
# lioness Kenton Rail Station 910GKTON HUBKNT None
# lioness North Wembley Rail Station 910GNWEMBLY HUBNWB None
# lioness Queens Park (London) Rail Station 910GQPRK HUBQPW None
# lioness South Hampstead Rail Station 910GSHMPSTD None South Hampstead Rail Station
# lioness South Kenton Rail Station 910GSKENTON HUBSOK None
# lioness Stonebridge Park Rail Station 910GSTNBGPK HUBSBP None
# lioness Watford High Street Rail Station 910GWATFDHS None Watford High Street Rail Station
# lioness Watford Junction Rail Station 910GWATFJDC HUBWFJ None
# lioness Willesden Junction Rail Station 910GWLSDJHL HUBWIJ None
# lioness Wembley Central Rail Station 910GWMBY HUBWMB None
# metropolitan Aldgate Underground Station 940GZZLUALD None Aldgate Underground Station
# metropolitan Amersham Underground Station 940GZZLUAMS HUBAMR None
# metropolitan Barbican Underground Station 940GZZLUBBN None Barbican Underground Station
# metropolitan Baker Street Underground Station 940GZZLUBST None Baker Street Underground Station
# metropolitan Chalfont & Latimer Underground Station 940GZZLUCAL HUBCFO None
# metropolitan Chesham Underground Station 940GZZLUCSM None Chesham Underground Station
# metropolitan Croxley Underground Station 940GZZLUCXY None Croxley Underground Station
# metropolitan Chorleywood Underground Station 940GZZLUCYD HUBCLW None
# metropolitan Eastcote Underground Station 940GZZLUEAE None Eastcote Underground Station
# metropolitan Euston Square Underground Station 940GZZLUESQ None Euston Square Underground Station
# metropolitan Farringdon Underground Station 940GZZLUFCN HUBZFD None
# metropolitan Finchley Road Underground Station 940GZZLUFYR None Finchley Road Underground Station
# metropolitan Great Portland Street Underground Station 940GZZLUGPS None Great Portland Street Underground Station
# metropolitan Hillingdon Underground Station 940GZZLUHGD None Hillingdon Underground Station
# metropolitan Harrow-on-the-Hill Underground Station 940GZZLUHOH HUBHOH None
# metropolitan Ickenham Underground Station 940GZZLUICK None Ickenham Underground Station
# metropolitan King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None
# metropolitan Liverpool Street Underground Station 940GZZLULVT HUBLST None
# metropolitan Moorgate Underground Station 940GZZLUMGT HUBZMG None
# metropolitan Moor Park Underground Station 940GZZLUMPK None Moor Park Underground Station
# metropolitan North Harrow Underground Station 940GZZLUNHA None North Harrow Underground Station
# metropolitan Northwick Park Underground Station 940GZZLUNKP None Northwick Park Underground Station
# metropolitan Northwood Underground Station 940GZZLUNOW None Northwood Underground Station
# metropolitan Northwood Hills Underground Station 940GZZLUNWH None Northwood Hills Underground Station
# metropolitan Pinner Underground Station 940GZZLUPNR None Pinner Underground Station
# metropolitan Preston Road Underground Station 940GZZLUPRD None Preston Road Underground Station
# metropolitan Rickmansworth Underground Station 940GZZLURKW HUBRIC None
# metropolitan Ruislip Manor Underground Station 940GZZLURSM None Ruislip Manor Underground Station
# metropolitan Ruislip Underground Station 940GZZLURSP None Ruislip Underground Station
# metropolitan Rayners Lane Underground Station 940GZZLURYL None Rayners Lane Underground Station
# metropolitan Uxbridge Underground Station 940GZZLUUXB None Uxbridge Underground Station
# metropolitan Watford Underground Station 940GZZLUWAF None Watford Underground Station
# metropolitan West Harrow Underground Station 940GZZLUWHW None West Harrow Underground Station
# metropolitan Wembley Park Underground Station 940GZZLUWYP None Wembley Park Underground Station
# mildmay Acton Central Rail Station 910GACTNCTL None Acton Central Rail Station
# mildmay Brondesbury Rail Station 910GBRBY None Brondesbury Rail Station
# mildmay Brondesbury Park Rail Station 910GBRBYPK None Brondesbury Park Rail Station
# mildmay Caledonian Road & Barnsbury Rail Station 910GCLDNNRB None Caledonian Road & Barnsbury Rail Station
# mildmay Clapham Junction Rail Station 910GCLPHMJ1 HUBCLJ None
# mildmay Clapham Junction Rail Station 910GCLPHMJC HUBCLJ None
# mildmay Camden Road Rail Station 910GCMDNRD None Camden Road Rail Station
# mildmay Canonbury Rail Station 910GCNNB None Canonbury Rail Station
# mildmay Imperial Wharf Rail Station 910GCSEAH HUBIMP None
# mildmay Dalston Kingsland Rail Station 910GDALSKLD None Dalston Kingsland Rail Station
# mildmay Finchley Road & Frognal Rail Station 910GFNCHLYR None Finchley Road & Frognal Rail Station
# mildmay Gunnersbury Rail Station 910GGNRSBRY HUBGUN None
# mildmay Gospel Oak Rail Station 910GGOSPLOK None Gospel Oak Rail Station
# mildmay Hackney Central Rail Station 910GHACKNYC None Hackney Central Rail Station
# mildmay Hackney Wick Rail Station 910GHACKNYW None Hackney Wick Rail Station
# mildmay Highbury & Islington Rail Station 910GHGHI HUBHHY None
# mildmay Hampstead Heath Rail Station 910GHMPSTDH None Hampstead Heath Rail Station
# mildmay Homerton Rail Station 910GHOMRTON None Homerton Rail Station
# mildmay Kensington (Olympia) Rail Station 910GKENOLYM HUBKPA None
# mildmay Kensal Rise Rail Station 910GKENR None Kensal Rise Rail Station
# mildmay Kew Gardens Rail Station 910GKEWGRDN HUBKWG None
# mildmay Kentish Town West Rail Station 910GKNTSHTW None Kentish Town West Rail Station
# mildmay Richmond (London) Rail Station 910GRICHMND HUBRMD None
# mildmay South Acton Rail Station 910GSACTON None South Acton Rail Station
# mildmay Shepherds Bush Rail Station 910GSHPDSB HUBSPB None
# mildmay Stratford (London) Rail Station 910GSTFD HUBSRA None
# mildmay West Brompton Rail Station 910GWBRMPTN HUBWBP None
# mildmay West Hampstead Rail Station 910GWHMDSTD HUBWHD None
# mildmay Willesden Junction Rail Station 910GWLSDJHL HUBWIJ None
# northern Battersea Power Station Underground Station 940GZZBPSUST None Battersea Power Station Underground Station
# northern Archway Underground Station 940GZZLUACY None Archway Underground Station
# northern Angel Underground Station 940GZZLUAGL None Angel Underground Station
# northern Balham Underground Station 940GZZLUBLM HUBBAL None
# northern Bank Underground Station 940GZZLUBNK HUBBAN None
# northern Borough Underground Station 940GZZLUBOR None Borough Underground Station
# northern Burnt Oak Underground Station 940GZZLUBTK None Burnt Oak Underground Station
# northern Brent Cross Underground Station 940GZZLUBTX None Brent Cross Underground Station
# northern Belsize Park Underground Station 940GZZLUBZP None Belsize Park Underground Station
# northern Chalk Farm Underground Station 940GZZLUCFM None Chalk Farm Underground Station
# northern Charing Cross Underground Station 940GZZLUCHX HUBCHX None
# northern Colindale Underground Station 940GZZLUCND None Colindale Underground Station
# northern Clapham Common Underground Station 940GZZLUCPC None Clapham Common Underground Station
# northern Clapham North Underground Station 940GZZLUCPN None Clapham North Underground Station
# northern Clapham South Underground Station 940GZZLUCPS None Clapham South Underground Station
# northern Colliers Wood Underground Station 940GZZLUCSD None Colliers Wood Underground Station
# northern Camden Town Underground Station 940GZZLUCTN None Camden Town Underground Station
# northern Elephant & Castle Underground Station 940GZZLUEAC HUBEPH None
# northern East Finchley Underground Station 940GZZLUEFY None East Finchley Underground Station
# northern Edgware Underground Station 940GZZLUEGW None Edgware Underground Station
# northern Embankment Underground Station 940GZZLUEMB None Embankment Underground Station
# northern Euston Underground Station 940GZZLUEUS HUBEUS None
# northern Finchley Central Underground Station 940GZZLUFYC None Finchley Central Underground Station
# northern Goodge Street Underground Station 940GZZLUGDG None Goodge Street Underground Station
# northern Golders Green Underground Station 940GZZLUGGN None Golders Green Underground Station
# northern High Barnet Underground Station 940GZZLUHBT None High Barnet Underground Station
# northern Hendon Central Underground Station 940GZZLUHCL None Hendon Central Underground Station
# northern Highgate Underground Station 940GZZLUHGT None Highgate Underground Station
# northern Hampstead Underground Station 940GZZLUHTD None Hampstead Underground Station
# northern Kennington Underground Station 940GZZLUKNG None Kennington Underground Station
# northern Kentish Town Underground Station 940GZZLUKSH HUBKTN None
# northern King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None
# northern London Bridge Underground Station 940GZZLULNB HUBLBG None
# northern Leicester Square Underground Station 940GZZLULSQ None Leicester Square Underground Station
# northern Morden Underground Station 940GZZLUMDN None Morden Underground Station
# northern Moorgate Underground Station 940GZZLUMGT HUBZMG None
# northern Mill Hill East Underground Station 940GZZLUMHL None Mill Hill East Underground Station
# northern Mornington Crescent Underground Station 940GZZLUMTC None Mornington Crescent Underground Station
# northern Old Street Underground Station 940GZZLUODS HUBOLD None
# northern Oval Underground Station 940GZZLUOVL None Oval Underground Station
# northern Stockwell Underground Station 940GZZLUSKW None Stockwell Underground Station
# northern South Wimbledon Underground Station 940GZZLUSWN None South Wimbledon Underground Station
# northern Totteridge & Whetstone Underground Station 940GZZLUTAW None Totteridge & Whetstone Underground Station
# northern Tooting Bec Underground Station 940GZZLUTBC None Tooting Bec Underground Station
# northern Tooting Broadway Underground Station 940GZZLUTBY None Tooting Broadway Underground Station
# northern Tottenham Court Road Underground Station 940GZZLUTCR HUBTCR None
# northern Tufnell Park Underground Station 940GZZLUTFP None Tufnell Park Underground Station
# northern West Finchley Underground Station 940GZZLUWFN None West Finchley Underground Station
# northern Waterloo Underground Station 940GZZLUWLO HUBWAT None
# northern Woodside Park Underground Station 940GZZLUWOP None Woodside Park Underground Station
# northern Warren Street Underground Station 940GZZLUWRR None Warren Street Underground Station
# northern Nine Elms Underground Station 940GZZNEUGST None Nine Elms Underground Station
# piccadilly Acton Town Underground Station 940GZZLUACT None Acton Town Underground Station
# piccadilly Alperton Underground Station 940GZZLUALP None Alperton Underground Station
# piccadilly Arnos Grove Underground Station 940GZZLUASG None Arnos Grove Underground Station
# piccadilly Arsenal Underground Station 940GZZLUASL None Arsenal Underground Station
# piccadilly Bounds Green Underground Station 940GZZLUBDS None Bounds Green Underground Station
# piccadilly Boston Manor Underground Station 940GZZLUBOS None Boston Manor Underground Station
# piccadilly Barons Court Underground Station 940GZZLUBSC None Barons Court Underground Station
# piccadilly Caledonian Road Underground Station 940GZZLUCAR None Caledonian Road Underground Station
# piccadilly Covent Garden Underground Station 940GZZLUCGN None Covent Garden Underground Station
# piccadilly Cockfosters Underground Station 940GZZLUCKS None Cockfosters Underground Station
# piccadilly Eastcote Underground Station 940GZZLUEAE None Eastcote Underground Station
# piccadilly Ealing Common Underground Station 940GZZLUECM None Ealing Common Underground Station
# piccadilly Earl's Court Underground Station 940GZZLUECT None Earl's Court Underground Station
# piccadilly Finsbury Park Underground Station 940GZZLUFPK HUBFPK None
# piccadilly Green Park Underground Station 940GZZLUGPK None Green Park Underground Station
# piccadilly Gloucester Road Underground Station 940GZZLUGTR None Gloucester Road Underground Station
# piccadilly Holborn Underground Station 940GZZLUHBN None Holborn Underground Station
# piccadilly Hillingdon Underground Station 940GZZLUHGD None Hillingdon Underground Station
# piccadilly Hatton Cross Underground Station 940GZZLUHNX None Hatton Cross Underground Station
# piccadilly Hyde Park Corner Underground Station 940GZZLUHPC None Hyde Park Corner Underground Station
# piccadilly Heathrow Terminal 4 Underground Station 940GZZLUHR4 HUBHX4 None
# piccadilly Heathrow Terminal 5 Underground Station 940GZZLUHR5 HUBHX5 None
# piccadilly Heathrow Terminals 2 & 3 Underground Station 940GZZLUHRC HUBH13 None
# piccadilly Hammersmith (Dist&Picc Line) Underground Station 940GZZLUHSD HUBHMS None
# piccadilly Hounslow Central Underground Station 940GZZLUHWC None Hounslow Central Underground Station
# piccadilly Hounslow East Underground Station 940GZZLUHWE None Hounslow East Underground Station
# piccadilly Hounslow West Underground Station 940GZZLUHWT None Hounslow West Underground Station
# piccadilly Holloway Road Underground Station 940GZZLUHWY None Holloway Road Underground Station
# piccadilly Ickenham Underground Station 940GZZLUICK None Ickenham Underground Station
# piccadilly Knightsbridge Underground Station 940GZZLUKNB None Knightsbridge Underground Station
# piccadilly King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None
# piccadilly Leicester Square Underground Station 940GZZLULSQ None Leicester Square Underground Station
# piccadilly Manor House Underground Station 940GZZLUMRH None Manor House Underground Station
# piccadilly North Ealing Underground Station 940GZZLUNEN None North Ealing Underground Station
# piccadilly Northfields Underground Station 940GZZLUNFD None Northfields Underground Station
# piccadilly Oakwood Underground Station 940GZZLUOAK None Oakwood Underground Station
# piccadilly Osterley Underground Station 940GZZLUOSY None Osterley Underground Station
# piccadilly Piccadilly Circus Underground Station 940GZZLUPCC None Piccadilly Circus Underground Station
# piccadilly Park Royal Underground Station 940GZZLUPKR None Park Royal Underground Station
# piccadilly Ruislip Manor Underground Station 940GZZLURSM None Ruislip Manor Underground Station
# piccadilly Ruislip Underground Station 940GZZLURSP None Ruislip Underground Station
# piccadilly Russell Square Underground Station 940GZZLURSQ None Russell Square Underground Station
# piccadilly Rayners Lane Underground Station 940GZZLURYL None Rayners Lane Underground Station
# piccadilly South Ealing Underground Station 940GZZLUSEA None South Ealing Underground Station
# piccadilly Southgate Underground Station 940GZZLUSGT None Southgate Underground Station
# piccadilly South Harrow Underground Station 940GZZLUSHH None South Harrow Underground Station
# piccadilly South Kensington Underground Station 940GZZLUSKS None South Kensington Underground Station
# piccadilly Sudbury Hill Underground Station 940GZZLUSUH None Sudbury Hill Underground Station
# piccadilly Sudbury Town Underground Station 940GZZLUSUT None Sudbury Town Underground Station
# piccadilly Turnham Green Underground Station 940GZZLUTNG None Turnham Green Underground Station
# piccadilly Turnpike Lane Underground Station 940GZZLUTPN None Turnpike Lane Underground Station
# piccadilly Uxbridge Underground Station 940GZZLUUXB None Uxbridge Underground Station
# piccadilly Wood Green Underground Station 940GZZLUWOG None Wood Green Underground Station
# suffragette Barking Rail Station 910GBARKING HUBBKG None
# suffragette Barking Riverside 910GBKRVS None Barking Riverside
# suffragette Blackhorse Road Rail Station 910GBLCHSRD HUBBHO None
# suffragette Crouch Hill Rail Station 910GCROUCHH None Crouch Hill Rail Station
# suffragette Gospel Oak Rail Station 910GGOSPLOK None Gospel Oak Rail Station
# suffragette Harringay Green Lanes Rail Station 910GHRGYGL None Harringay Green Lanes Rail Station
# suffragette Leyton Midland Road Rail Station 910GLEYTNMR None Leyton Midland Road Rail Station
# suffragette Leytonstone High Road Rail Station 910GLYTNSHR None Leytonstone High Road Rail Station
# suffragette South Tottenham Rail Station 910GSTOTNHM None South Tottenham Rail Station
# suffragette Upper Holloway Rail Station 910GUPRHLWY None Upper Holloway Rail Station
# suffragette Woodgrange Park Rail Station 910GWDGRNPK None Woodgrange Park Rail Station
# suffragette Walthamstow Queens Road Rail Station 910GWLTHQRD None Walthamstow Queens Road Rail Station
# suffragette Wanstead Park Rail Station 910GWNSTDPK None Wanstead Park Rail Station
# tram Addiscombe 940GZZCRADD None Addiscombe
# tram Addiscombe 940GZZCRADD None Addiscombe
# tram Addington Village 940GZZCRADV None Addington Village
# tram Addington Village 940GZZCRADV None Addington Village
# tram Ampere Way 940GZZCRAMP None Ampere Way
# tram Ampere Way 940GZZCRAMP None Ampere Way
# tram Arena 940GZZCRARA None Arena
# tram Arena 940GZZCRARA None Arena
# tram Avenue Road 940GZZCRAVE None Avenue Road
# tram Avenue Road 940GZZCRAVE None Avenue Road
# tram Beddington Lane 940GZZCRBED None Beddington Lane
# tram Beddington Lane 940GZZCRBED None Beddington Lane
# tram Beckenham Junction 940GZZCRBEK HUBBEK None
# tram Belgrave Walk 940GZZCRBGV None Belgrave Walk
# tram Belgrave Walk 940GZZCRBGV None Belgrave Walk
# tram Birkbeck 940GZZCRBIR HUBBIR None
# tram Blackhorse Lane 940GZZCRBLA None Blackhorse Lane
# tram Blackhorse Lane 940GZZCRBLA None Blackhorse Lane
# tram Beckenham Road 940GZZCRBRD None Beckenham Road
# tram George Street 940GZZCRCEN None George Street
# tram Church Street 940GZZCRCHR None Church Street
# tram Coombe Lane 940GZZCRCOO None Coombe Lane
# tram Coombe Lane 940GZZCRCOO None Coombe Lane
# tram Centrale 940GZZCRCTR None Centrale
# tram Dundonald Road 940GZZCRDDR None Dundonald Road
# tram Dundonald Road 940GZZCRDDR None Dundonald Road
# tram East Croydon 940GZZCRECR HUBECY None
# tram East Croydon 940GZZCRECR HUBECY None
# tram Elmers End 940GZZCRELM HUBELM None
# tram Fieldway 940GZZCRFLD None Fieldway
# tram Fieldway 940GZZCRFLD None Fieldway
# tram Gravel Hill 940GZZCRGRA None Gravel Hill
# tram Gravel Hill 940GZZCRGRA None Gravel Hill
# tram Harrington Road 940GZZCRHAR None Harrington Road
# tram Harrington Road 940GZZCRHAR None Harrington Road
# tram King Henry's Drive 940GZZCRKGH None King Henry's Drive
# tram King Henry's Drive 940GZZCRKGH None King Henry's Drive
# tram Lebanon Road 940GZZCRLEB None Lebanon Road
# tram Lebanon Road 940GZZCRLEB None Lebanon Road
# tram Lloyd Park 940GZZCRLOY None Lloyd Park
# tram Lloyd Park 940GZZCRLOY None Lloyd Park
# tram Mitcham 940GZZCRMCH None Mitcham
# tram Mitcham 940GZZCRMCH None Mitcham
# tram Morden Road 940GZZCRMDN None Morden Road
# tram Morden Road 940GZZCRMDN None Morden Road
# tram Mitcham Junction 940GZZCRMJT HUBMJT None
# tram Mitcham Junction 940GZZCRMJT HUBMJT None
# tram Merton Park 940GZZCRMTP None Merton Park
# tram Merton Park 940GZZCRMTP None Merton Park
# tram New Addington 940GZZCRNWA None New Addington
# tram Phipps Bridge 940GZZCRPHI None Phipps Bridge
# tram Phipps Bridge 940GZZCRPHI None Phipps Bridge
# tram Reeves Corner 940GZZCRRVC None Reeves Corner
# tram Sandilands 940GZZCRSAN None Sandilands
# tram Sandilands 940GZZCRSAN None Sandilands
# tram Therapia Lane 940GZZCRTPA None Therapia Lane
# tram Therapia Lane 940GZZCRTPA None Therapia Lane
# tram Waddon Marsh 940GZZCRWAD None Waddon Marsh
# tram Waddon Marsh 940GZZCRWAD None Waddon Marsh
# tram Wandle Park 940GZZCRWAN None Wandle Park
# tram Wandle Park 940GZZCRWAN None Wandle Park
# tram West Croydon 940GZZCRWCR HUBWCY None
# tram Wellesley Road 940GZZCRWEL None Wellesley Road
# tram Wimbledon 940GZZCRWMB HUBWIM None
# tram Woodside 940GZZCRWOD None Woodside
# tram Woodside 940GZZCRWOD None Woodside
# tram Addiscombe Tram Stop 940GZZCRADD None Addiscombe Tram Stop
# tram Addington Village Tram Stop 940GZZCRADV None Addington Village Tram Stop
# tram Ampere Way Tram Stop 940GZZCRAMP None Ampere Way Tram Stop
# tram Arena Tram Stop 940GZZCRARA None Arena Tram Stop
# tram Avenue Road Tram Stop 940GZZCRAVE None Avenue Road Tram Stop
# tram Beddington Lane Tram Stop 940GZZCRBED None Beddington Lane Tram Stop
# tram Beckenham Junction Tram Stop 940GZZCRBEK HUBBEK None
# tram Belgrave Walk Tram Stop 940GZZCRBGV None Belgrave Walk Tram Stop
# tram Birkbeck Tram Stop 940GZZCRBIR HUBBIR None
# tram Blackhorse Lane Tram Stop 940GZZCRBLA None Blackhorse Lane Tram Stop
# tram Beckenham Road Tram Stop 940GZZCRBRD None Beckenham Road Tram Stop
# tram George Street Tram Stop 940GZZCRCEN None George Street Tram Stop
# tram Church Street Tram Stop 940GZZCRCHR None Church Street Tram Stop
# tram Coombe Lane Tram Stop 940GZZCRCOO None Coombe Lane Tram Stop
# tram Centrale Tram Stop 940GZZCRCTR None Centrale Tram Stop
# tram Dundonald Road Tram Stop 940GZZCRDDR None Dundonald Road Tram Stop
# tram East Croydon Tram Stop 940GZZCRECR HUBECY None
# tram Elmers End Tram Stop 940GZZCRELM HUBELM None
# tram Fieldway Tram Stop 940GZZCRFLD None Fieldway Tram Stop
# tram Gravel Hill Tram Stop 940GZZCRGRA None Gravel Hill Tram Stop
# tram Harrington Road Tram Stop 940GZZCRHAR None Harrington Road Tram Stop
# tram King Henry's Drive Tram Stop 940GZZCRKGH None King Henry's Drive Tram Stop
# tram Lebanon Road Tram Stop 940GZZCRLEB None Lebanon Road Tram Stop
# tram Lloyd Park Tram Stop 940GZZCRLOY None Lloyd Park Tram Stop
# tram Mitcham Tram Stop 940GZZCRMCH None Mitcham Tram Stop
# tram Morden Road Tram Stop 940GZZCRMDN None Morden Road Tram Stop
# tram Mitcham Junction Tram Stop 940GZZCRMJT HUBMJT None
# tram Merton Park Tram Stop 940GZZCRMTP None Merton Park Tram Stop
# tram New Addington Tram Stop 940GZZCRNWA None New Addington Tram Stop
# tram Phipps Bridge Tram Stop 940GZZCRPHI None Phipps Bridge Tram Stop
# tram Reeves Corner Tram Stop 940GZZCRRVC None Reeves Corner Tram Stop
# tram Sandilands Tram Stop 940GZZCRSAN None Sandilands Tram Stop
# tram Therapia Lane Tram Stop 940GZZCRTPA None Therapia Lane Tram Stop
# tram Waddon Marsh Tram Stop 940GZZCRWAD None Waddon Marsh Tram Stop
# tram Wandle Park Tram Stop 940GZZCRWAN None Wandle Park Tram Stop
# tram West Croydon Tram Stop 940GZZCRWCR HUBWCY None
# tram Wellesley Road Tram Stop 940GZZCRWEL None Wellesley Road Tram Stop
# tram Wimbledon Tram Stop 940GZZCRWMB HUBWIM None
# tram Woodside Tram Stop 940GZZCRWOD None Woodside Tram Stop
# victoria Blackhorse Road Underground Station 940GZZLUBLR HUBBHO None
# victoria Brixton Underground Station 940GZZLUBXN HUBBRX None
# victoria Euston Underground Station 940GZZLUEUS HUBEUS None
# victoria Finsbury Park Underground Station 940GZZLUFPK HUBFPK None
# victoria Green Park Underground Station 940GZZLUGPK None Green Park Underground Station
# victoria Highbury & Islington Underground Station 940GZZLUHAI HUBHHY None
# victoria King's Cross St. Pancras Underground Station 940GZZLUKSX HUBKGX None
# victoria Oxford Circus Underground Station 940GZZLUOXC None Oxford Circus Underground Station
# ...
# North Harrow Underground Station - 940GZZLUNHA - metropolitan = None
# North Wembley Rail Station - 910GNWEMBLY - lioness = HUBNWB
# North Wembley Underground Station - 940GZZLUNWY - bakerloo = HUBNWB
# Northfields Underground Station - 940GZZLUNFD - piccadilly = None
# Northolt Underground Station - 940GZZLUNHT - central = None
# Northwick Park Underground Station - 940GZZLUNKP - metropolitan = None
# Northwood Hills Underground Station - 940GZZLUNWH - metropolitan = None
# Northwood Underground Station - 940GZZLUNOW - metropolitan = None
# Norwood Junction Rail Station - 910GNORWDJ - windrush = HUBNWD
# Notting Hill Gate Underground Station - 940GZZLUNHG - central = None
# Notting Hill Gate Underground Station - 940GZZLUNHG - circle = None
# Notting Hill Gate Underground Station - 940GZZLUNHG - district = None
# Oakwood Underground Station - 940GZZLUOAK - piccadilly = None
# Old Street Underground Station - 940GZZLUODS - northern = HUBOLD
# Osterley Underground Station - 940GZZLUOSY - piccadilly = None
# Oval Underground Station - 940GZZLUOVL - northern = None
# Oxford Circus Underground Station - 940GZZLUOXC - bakerloo = None
# Oxford Circus Underground Station - 940GZZLUOXC - central = None
# Oxford Circus Underground Station - 940GZZLUOXC - victoria = None
# Paddington (H&C Line)-Underground - 940GZZLUPAH - circle = HUBPAD
# Paddington (H&C Line)-Underground - 940GZZLUPAH - hammersmith-city = HUBPAD
# Paddington - 910GPADTLL - elizabeth = HUBPAD
# Paddington Underground Station - 940GZZLUPAC - bakerloo = HUBPAD
# Paddington Underground Station - 940GZZLUPAC - circle = HUBPAD
# Paddington Underground Station - 940GZZLUPAC - district = HUBPAD
# Park Royal Underground Station - 940GZZLUPKR - piccadilly = None
# Parsons Green Underground Station - 940GZZLUPSG - district = None
# Peckham Rye Rail Station - 910GPCKHMRY - windrush = None
# Penge West Rail Station - 910GPENEW - windrush = None
# Perivale Underground Station - 940GZZLUPVL - central = None
# Phipps Bridge - 940GZZCRPHI - tram = None
# Phipps Bridge - 940GZZCRPHI - tram = None
# Phipps Bridge Tram Stop - 940GZZCRPHI - tram = None
# Piccadilly Circus Underground Station - 940GZZLUPCC - bakerloo = None
# Piccadilly Circus Underground Station - 940GZZLUPCC - piccadilly = None
# Pimlico Underground Station - 940GZZLUPCO - victoria = None
# Pinner Underground Station - 940GZZLUPNR - metropolitan = None
# Plaistow Underground Station - 940GZZLUPLW - district = None
# Plaistow Underground Station - 940GZZLUPLW - hammersmith-city = None
# Pontoon Dock DLR Station - 940GZZDLPDK - dlr = None
# Poplar DLR Station - 940GZZDLPOP - dlr = None
# Preston Road Underground Station - 940GZZLUPRD - metropolitan = None
# Prince Regent DLR Station - 940GZZDLPRE - dlr = None
# Pudding Mill Lane DLR Station - 940GZZDLPUD - dlr = None
# Putney Bridge Underground Station - 940GZZLUPYB - district = None
# Queen's Park Underground Station - 940GZZLUQPS - bakerloo = HUBQPW
# Queens Park (London) Rail Station - 910GQPRK - lioness = HUBQPW
# Queens Road Peckham Rail Station - 910GPCKHMQD - windrush = None
# Queensbury Underground Station - 940GZZLUQBY - jubilee = None
# Queensway Underground Station - 940GZZLUQWY - central = None
# Ravenscourt Park Underground Station - 940GZZLURVP - district = None
# Rayners Lane Underground Station - 940GZZLURYL - metropolitan = None
# Rayners Lane Underground Station - 940GZZLURYL - piccadilly = None
# Reading Rail Station - 910GRDNGSTN - elizabeth = None
# Rectory Road Rail Station - 910GRCTRYRD - weaver = None
# Redbridge Underground Station - 940GZZLURBG - central = None
# Reeves Corner - 940GZZCRRVC - tram = None
# Reeves Corner Tram Stop - 940GZZCRRVC - tram = None
# Regent's Park Underground Station - 940GZZLURGP - bakerloo = None
# Richmond (London) Rail Station - 910GRICHMND - mildmay = HUBRMD
# Richmond Underground Station - 940GZZLURMD - district = HUBRMD
# Rickmansworth Underground Station - 940GZZLURKW - metropolitan = HUBRIC
# Roding Valley Underground Station - 940GZZLURVY - central = None
# Romford Rail Station - 910GROMFORD - elizabeth = None
# Romford Rail Station - 910GROMFORD - liberty = None
# Rotherhithe Rail Station - 910GRTHERHI - windrush = None
# Royal Albert DLR Station - 940GZZDLRAL - dlr = None
# Royal Oak Underground Station - 940GZZLURYO - circle = None
# Royal Oak Underground Station - 940GZZLURYO - hammersmith-city = None
# Royal Victoria DLR Station - 940GZZDLRVC - dlr = HUBRVC
# Ruislip Gardens Underground Station - 940GZZLURSG - central = None
# Ruislip Manor Underground Station - 940GZZLURSM - metropolitan = None
# Ruislip Manor Underground Station - 940GZZLURSM - piccadilly = None
# Ruislip Underground Station - 940GZZLURSP - metropolitan = None
# Ruislip Underground Station - 940GZZLURSP - piccadilly = None
# Russell Square Underground Station - 940GZZLURSQ - piccadilly = None
# Sandilands - 940GZZCRSAN - tram = None
# Sandilands - 940GZZCRSAN - tram = None
# Sandilands Tram Stop - 940GZZCRSAN - tram = None
# Seven Kings Rail Station - 910GSVNKNGS - elizabeth = None
# Seven Sisters Rail Station - 910GSEVNSIS - weaver = HUBSVS
# Seven Sisters Underground Station - 940GZZLUSVS - victoria = HUBSVS
# Shadwell DLR Station - 940GZZDLSHA - dlr = HUBSDE
# Shadwell Rail Station - 910GSHADWEL - windrush = HUBSDE
# Shenfield Rail Station - 910GSHENFLD - elizabeth = None
# Shepherd's Bush (Central) Underground Station - 940GZZLUSBC - central = HUBSPB
# Shepherd's Bush Market Underground Station - 940GZZLUSBM - circle = None
# Shepherd's Bush Market Underground Station - 940GZZLUSBM - hammersmith-city = None
# Shepherds Bush Rail Station - 910GSHPDSB - mildmay = HUBSPB
# Shoreditch High Street Rail Station - 910GSHRDHST - windrush = None
# Silver Street Rail Station - 910GSIVRST - weaver = None
# Sloane Square Underground Station - 940GZZLUSSQ - circle = None
# Sloane Square Underground Station - 940GZZLUSSQ - district = None
# Slough Rail Station - 910GSLOUGH - elizabeth = None
# Snaresbrook Underground Station - 940GZZLUSNB - central = None
# South Acton Rail Station - 910GSACTON - mildmay = None
# South Ealing Underground Station - 940GZZLUSEA - piccadilly = None
# South Hampstead Rail Station - 910GSHMPSTD - lioness = None
# South Harrow Underground Station - 940GZZLUSHH - piccadilly = None
# South Kensington Underground Station - 940GZZLUSKS - circle = None
# South Kensington Underground Station - 940GZZLUSKS - district = None
# South Kensington Underground Station - 940GZZLUSKS - piccadilly = None
# South Kenton Rail Station - 910GSKENTON - lioness = HUBSOK
# South Kenton Underground Station - 940GZZLUSKT - bakerloo = HUBSOK
# South Quay DLR Station - 940GZZDLSOQ - dlr = None
# South Ruislip Underground Station - 940GZZLUSRP - central = HUBSRU
# South Tottenham Rail Station - 910GSTOTNHM - suffragette = None
# South Wimbledon Underground Station - 940GZZLUSWN - northern = None
# South Woodford Underground Station - 940GZZLUSWF - central = None
# Southall Rail Station - 910GSTHALL - elizabeth = None
# Southbury Rail Station - 910GSBURY - weaver = None
# Southfields Underground Station - 940GZZLUSFS - district = None
# Southgate Underground Station - 940GZZLUSGT - piccadilly = None
# Southwark Underground Station - 940GZZLUSWK - jubilee = None
# St James Street (London) Rail Station - 910GSTJMSST - weaver = None
# St. James's Park Underground Station - 940GZZLUSJP - circle = None
# St. James's Park Underground Station - 940GZZLUSJP - district = None
# St. John's Wood Underground Station - 940GZZLUSJW - jubilee = None
# St. Paul's Underground Station - 940GZZLUSPU - central = None
# Stamford Brook Underground Station - 940GZZLUSFB - district = None
# Stamford Hill Rail Station - 910GSTMFDHL - weaver = None
# Stanmore Underground Station - 940GZZLUSTM - jubilee = None
# Star Lane DLR Station - 940GZZDLSTL - dlr = None
# Stepney Green Underground Station - 940GZZLUSGN - district = None
# Stepney Green Underground Station - 940GZZLUSGN - hammersmith-city = None
# Stockwell Underground Station - 940GZZLUSKW - northern = None
# Stockwell Underground Station - 940GZZLUSKW - victoria = None
# Stoke Newington Rail Station - 910GSTKNWNG - weaver = None
# Stonebridge Park Rail Station - 910GSTNBGPK - lioness = HUBSBP
# Stonebridge Park Underground Station - 940GZZLUSGP - bakerloo = HUBSBP
# Stratford (London) Rail Station - 910GSTFD - elizabeth = HUBSRA
# Stratford (London) Rail Station - 910GSTFD - mildmay = HUBSRA
# Stratford DLR Station - 940GZZDLSTD - dlr = HUBSRA
# Stratford High Street DLR Station - 940GZZDLSHS - dlr = None
# Stratford International DLR Station - 940GZZDLSIT - dlr = None
# Stratford Underground Station - 940GZZLUSTD - central = HUBSRA
# Stratford Underground Station - 940GZZLUSTD - jubilee = HUBSRA
# Sudbury Hill Underground Station - 940GZZLUSUH - piccadilly = None
# Sudbury Town Underground Station - 940GZZLUSUT - piccadilly = None
# Surrey Quays Rail Station - 910GSURREYQ - windrush = None
# Swiss Cottage Underground Station - 940GZZLUSWC - jubilee = None
# Sydenham Rail Station - 910GSYDENHM - windrush = HUBSYD
# Taplow Rail Station - 910GTAPLOW - elizabeth = None
# Temple Underground Station - 940GZZLUTMP - circle = None
# Temple Underground Station - 940GZZLUTMP - district = None
# Theobalds Grove Rail Station - 910GTHBLDSG - weaver = None
# Therapia Lane - 940GZZCRTPA - tram = None
# Therapia Lane - 940GZZCRTPA - tram = None
# Therapia Lane Tram Stop - 940GZZCRTPA - tram = None
# Theydon Bois Underground Station - 940GZZLUTHB - central = None
# Tooting Bec Underground Station - 940GZZLUTBC - northern = None
# Tooting Broadway Underground Station - 940GZZLUTBY - northern = None
# Tottenham Court Road - 910GTOTCTRD - elizabeth = HUBTCR
# Tottenham Court Road Underground Station - 940GZZLUTCR - central = HUBTCR
# Tottenham Court Road Underground Station - 940GZZLUTCR - northern = HUBTCR
# Tottenham Hale Underground Station - 940GZZLUTMH - victoria = HUBTOM
# Totteridge & Whetstone Underground Station - 940GZZLUTAW - northern = None
# Tower Gateway DLR Station - 940GZZDLTWG - dlr = HUBTOG
# Tower Hill Underground Station - 940GZZLUTWH - circle = None
# Tower Hill Underground Station - 940GZZLUTWH - district = None
# Tufnell Park Underground Station - 940GZZLUTFP - northern = None
# Turkey Street Rail Station - 910GTURKYST - weaver = None
# Turnham Green Underground Station - 940GZZLUTNG - district = None
# Turnham Green Underground Station - 940GZZLUTNG - piccadilly = None
# Turnpike Lane Underground Station - 940GZZLUTPN - piccadilly = None
# Twyford Rail Station - 910GTWYFORD - elizabeth = None
# Upminster Bridge Underground Station - 940GZZLUUPB - district = None
# Upminster Rail Station - 910GUPMNSTR - liberty = HUBUPM
# Upminster Underground Station - 940GZZLUUPM - district = HUBUPM
# Upney Underground Station - 940GZZLUUPY - district = None
# Upper Holloway Rail Station - 910GUPRHLWY - suffragette = None
# Upton Park Underground Station - 940GZZLUUPK - district = None
# Upton Park Underground Station - 940GZZLUUPK - hammersmith-city = None
# Uxbridge Underground Station - 940GZZLUUXB - metropolitan = None
# Uxbridge Underground Station - 940GZZLUUXB - piccadilly = None
# Vauxhall Underground Station - 940GZZLUVXL - victoria = HUBVXH
# Victoria Underground Station - 940GZZLUVIC - circle = HUBVIC
# Victoria Underground Station - 940GZZLUVIC - district = HUBVIC
# Victoria Underground Station - 940GZZLUVIC - victoria = HUBVIC
# Waddon Marsh - 940GZZCRWAD - tram = None
# Waddon Marsh - 940GZZCRWAD - tram = None
# Waddon Marsh Tram Stop - 940GZZCRWAD - tram = None
# Walthamstow Central Rail Station - 910GWLTWCEN - weaver = HUBWHC
# Walthamstow Central Underground Station - 940GZZLUWWL - victoria = HUBWHC
# Walthamstow Queens Road Rail Station - 910GWLTHQRD - suffragette = None
# Wandle Park - 940GZZCRWAN - tram = None
# Wandle Park - 940GZZCRWAN - tram = None
# Wandle Park Tram Stop - 940GZZCRWAN - tram = None
# Wandsworth Road Rail Station - 910GWNDSWRD - windrush = None
# Wanstead Park Rail Station - 910GWNSTDPK - suffragette = None
# Wanstead Underground Station - 940GZZLUWSD - central = None
# Wapping Rail Station - 910GWAPPING - windrush = None
# Warren Street Underground Station - 940GZZLUWRR - northern = None
# Warren Street Underground Station - 940GZZLUWRR - victoria = None
# Warwick Avenue Underground Station - 940GZZLUWKA - bakerloo = None
# Waterloo Underground Station - 940GZZLUWLO - bakerloo = HUBWAT
# Waterloo Underground Station - 940GZZLUWLO - jubilee = HUBWAT
# Waterloo Underground Station - 940GZZLUWLO - northern = HUBWAT
# Waterloo Underground Station - 940GZZLUWLO - waterloo-city = HUBWAT
# Watford High Street Rail Station - 910GWATFDHS - lioness = None
# Watford Junction Rail Station - 910GWATFJDC - lioness = HUBWFJ
# Watford Underground Station - 940GZZLUWAF - metropolitan = None
# Wellesley Road - 940GZZCRWEL - tram = None
# Wellesley Road Tram Stop - 940GZZCRWEL - tram = None
# Wembley Central Rail Station - 910GWMBY - lioness = HUBWMB
# Wembley Central Underground Station - 940GZZLUWYC - bakerloo = HUBWMB
# Wembley Park Underground Station - 940GZZLUWYP - jubilee = None
# Wembley Park Underground Station - 940GZZLUWYP - metropolitan = None
# West Acton Underground Station - 940GZZLUWTA - central = None
# West Brompton Rail Station - 910GWBRMPTN - mildmay = HUBWBP
# West Brompton Underground Station - 940GZZLUWBN - district = HUBWBP
# West Croydon - 940GZZCRWCR - tram = HUBWCY
# West Croydon Rail Station - 910GWCROYDN - windrush = HUBWCY
# West Croydon Tram Stop - 940GZZCRWCR - tram = HUBWCY
# West Drayton Rail Station - 910GWDRYTON - elizabeth = None
# West Ealing Rail Station - 910GWEALING - elizabeth = None
# West Finchley Underground Station - 940GZZLUWFN - northern = None
# West Ham DLR Station - 940GZZDLWHM - dlr = HUBWEH
# West Ham Underground Station - 940GZZLUWHM - district = HUBWEH
# West Ham Underground Station - 940GZZLUWHM - hammersmith-city = HUBWEH
# West Ham Underground Station - 940GZZLUWHM - jubilee = HUBWEH
# West Hampstead Rail Station - 910GWHMDSTD - mildmay = HUBWHD
# West Hampstead Underground Station - 940GZZLUWHP - jubilee = HUBWHD
# West Harrow Underground Station - 940GZZLUWHW - metropolitan = None
# West India Quay DLR Station - 940GZZDLWIQ - dlr = None
# West Kensington Underground Station - 940GZZLUWKN - district = None
# West Ruislip Underground Station - 940GZZLUWRP - central = HUBWRU
# West Silvertown DLR Station - 940GZZDLWSV - dlr = None
# Westbourne Park Underground Station - 940GZZLUWSP - circle = None
# Westbourne Park Underground Station - 940GZZLUWSP - hammersmith-city = None
# Westferry DLR Station - 940GZZDLWFE - dlr = None
# Westminster Underground Station - 940GZZLUWSM - circle = HUBWSM
# Westminster Underground Station - 940GZZLUWSM - district = HUBWSM
# Westminster Underground Station - 940GZZLUWSM - jubilee = HUBWSM
# White City Underground Station - 940GZZLUWCY - central = None
# White Hart Lane Rail Station - 910GWHHRTLA - weaver = None
# Whitechapel - 910GWCHAPXR - elizabeth = HUBZWL
# Whitechapel Rail Station - 910GWCHAPEL - windrush = HUBZWL
# Whitechapel Underground Station - 940GZZLUWPL - district = HUBZWL
# Whitechapel Underground Station - 940GZZLUWPL - hammersmith-city = HUBZWL
# Willesden Green Underground Station - 940GZZLUWIG - jubilee = None
# Willesden Junction Rail Station - 910GWLSDJHL - lioness = HUBWIJ
# Willesden Junction Rail Station - 910GWLSDJHL - mildmay = HUBWIJ
# Willesden Junction Underground Station - 940GZZLUWJN - bakerloo = HUBWIJ
# Wimbledon - 940GZZCRWMB - tram = HUBWIM
# Wimbledon Park Underground Station - 940GZZLUWIP - district = None
# Wimbledon Tram Stop - 940GZZCRWMB - tram = HUBWIM
# Wimbledon Underground Station - 940GZZLUWIM - district = HUBWIM
# Wood Green Underground Station - 940GZZLUWOG - piccadilly = None
# Wood Lane Underground Station - 940GZZLUWLA - circle = None
# Wood Lane Underground Station - 940GZZLUWLA - hammersmith-city = None
# Wood Street Rail Station - 910GWDST - weaver = None
# Woodford Underground Station - 940GZZLUWOF - central = None
# Woodgrange Park Rail Station - 910GWDGRNPK - suffragette = None
# Woodside - 940GZZCRWOD - tram = None
# Woodside - 940GZZCRWOD - tram = None
# Woodside Park Underground Station - 940GZZLUWOP - northern = None
# Woodside Tram Stop - 940GZZCRWOD - tram = None
# Woolwich - 910GWOLWXR - elizabeth = None
# Woolwich Arsenal DLR Station - 940GZZDLWLA - dlr = HUBWWA

# %%
id = "district"
direction = "outbound"
stops = fetch_tfl_data(f"/Line/{id}/Route/Sequence/{direction}")
#pprint(stops, depth=1, compact=True)
pprint(stops["stations"][-1], depth=3, compact=True)
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, '
#           'Tfl.Api.Presentation.Entities',
#  'icsId': '1000268',
#  'id': 'HUBZWL',
#  'lat': 51.519498,
#  'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': '205',
#             'name': '205',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/205'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': '25',
#             'name': '25',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/25'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': '254',
#             'name': '254',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/254'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'd3',
#             'name': 'D3',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/d3'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'district',
#             'name': 'District',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/district'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'elizabeth',
#             'name': 'Elizabeth line',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/elizabeth'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'hammersmith-city',
#             'name': 'Hammersmith & City',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/hammersmith-city'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'n205',
#             'name': 'N205',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/n205'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'n25',
#             'name': 'N25',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/n25'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'n253',
#             'name': 'N253',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/n253'},
#            {'$type': 'Tfl.Api.Presentation.Entities.Identifier, '
#                      'Tfl.Api.Presentation.Entities',
#             'crowding': {...},
#             'id': 'windrush',
#             'name': 'Windrush',
#             'routeType': 'Unknown',
#             'status': 'Unknown',
#             'type': 'Line',
#             'uri': '/Line/windrush'}],
#  'lon': -0.059858,
#  'modes': ['bus', 'elizabeth-line', 'overground', 'tube'],
#  'name': 'Whitechapel',
#  'status': True,
#  'stopType': 'TransportInterchange',
#  'zone': '2'}

# %%
route_stations = []

for station in stops["orderedLineRoutes"][0]["naptanIds"]: # Routes with variations have multiple  entries here
    print(f"{id}: {station}-{station_id[station]}")
    route_stations.append(f"{station}-{id}")
# Out:
# district: 940GZZLUEBY-Ealing Broadway Underground Station
# district: 940GZZLUECM-Ealing Common Underground Station
# district: 940GZZLUACT-Acton Town Underground Station
# district: 940GZZLUCWP-Chiswick Park Underground Station
# district: 940GZZLUTNG-Turnham Green Underground Station
# district: 940GZZLUSFB-Stamford Brook Underground Station
# district: 940GZZLURVP-Ravenscourt Park Underground Station
# district: 940GZZLUHSD-Hammersmith (Dist&Picc Line) Underground Station
# district: 940GZZLUBSC-Barons Court Underground Station
# district: 940GZZLUWKN-West Kensington Underground Station
# district: 940GZZLUECT-Earl's Court Underground Station
# district: 940GZZLUGTR-Gloucester Road Underground Station
# district: 940GZZLUSKS-South Kensington Underground Station
# district: 940GZZLUSSQ-Sloane Square Underground Station
# district: 940GZZLUVIC-Victoria Underground Station
# district: 940GZZLUSJP-St. James's Park Underground Station
# district: 940GZZLUWSM-Westminster Underground Station
# district: 940GZZLUEMB-Embankment Underground Station
# district: 940GZZLUTMP-Temple Underground Station
# district: 940GZZLUBKF-Blackfriars Underground Station
# district: 940GZZLUMSH-Mansion House Underground Station
# district: 940GZZLUCST-Cannon Street Underground Station
# district: 940GZZLUMMT-Monument Underground Station
# district: 940GZZLUTWH-Tower Hill Underground Station
# district: 940GZZLUADE-Aldgate East Underground Station
# district: 940GZZLUWPL-Whitechapel Underground Station
# district: 940GZZLUSGN-Stepney Green Underground Station
# district: 940GZZLUMED-Mile End Underground Station
# district: 940GZZLUBWR-Bow Road Underground Station
# district: 940GZZLUBBB-Bromley-by-Bow Underground Station
# district: 940GZZLUWHM-West Ham Underground Station
# district: 940GZZLUPLW-Plaistow Underground Station
# district: 940GZZLUUPK-Upton Park Underground Station
# district: 940GZZLUEHM-East Ham Underground Station
# district: 940GZZLUBKG-Barking Underground Station
# district: 940GZZLUUPY-Upney Underground Station
# district: 940GZZLUBEC-Becontree Underground Station
# district: 940GZZLUDGY-Dagenham Heathway Underground Station
# district: 940GZZLUDGE-Dagenham East Underground Station
# district: 940GZZLUEPK-Elm Park Underground Station
# district: 940GZZLUHCH-Hornchurch Underground Station
# district: 940GZZLUUPB-Upminster Bridge Underground Station
# district: 940GZZLUUPM-Upminster Underground Station

# %%
route_stations = []

for station in stops["orderedLineRoutes"][0]["naptanIds"]: # Routes with variations have multiple  entries here
    print(f"{id}: {station}-{station_id[station]}")
    route_stations.append(f"{station}-{id}")
# Out:
# windrush: 910GHGHI-Highbury & Islington Rail Station
# windrush: 910GCNNB-Canonbury Rail Station
# windrush: 910GDALS-Dalston Junction Rail Station
# windrush: 910GHAGGERS-Haggerston Rail Station
# windrush: 910GHOXTON-Hoxton Rail Station
# windrush: 910GSHRDHST-Shoreditch High Street Rail Station
# windrush: 910GWCHAPEL-Whitechapel Rail Station
# windrush: 910GSHADWEL-Shadwell Rail Station
# windrush: 910GWAPPING-Wapping Rail Station
# windrush: 910GRTHERHI-Rotherhithe Rail Station
# windrush: 910GCNDAW-Canada Water Rail Station
# windrush: 910GSURREYQ-Surrey Quays Rail Station
# windrush: 910GNWCRELL-New Cross ELL Rail Station

# %%
print(route_stations)
# Out:
# ['910GABWDXR-elizabeth', '910GWOLWXR-elizabeth', '910GCSTMHSXR-elizabeth', '910GCANWHRF-elizabeth', '910GWCHAPXR-elizabeth', '910GLIVSTLL-elizabeth', '910GFRNDXR-elizabeth', '910GTOTCTRD-elizabeth', '910GBONDST-elizabeth', '910GPADTLL-elizabeth', '910GACTONML-elizabeth', '910GEALINGB-elizabeth', '910GWEALING-elizabeth', '910GHANWELL-elizabeth', '910GSTHALL-elizabeth', '910GHAYESAH-elizabeth', '910GHTRWAPT-elizabeth', '910GHTRWTM4-elizabeth']

# %%
for x,y in zip(route_stations, route_stations[1:]):
    print(x, y)
# Out:
# 910GABWDXR-elizabeth 910GWOLWXR-elizabeth
# 910GWOLWXR-elizabeth 910GCSTMHSXR-elizabeth
# 910GCSTMHSXR-elizabeth 910GCANWHRF-elizabeth
# 910GCANWHRF-elizabeth 910GWCHAPXR-elizabeth
# 910GWCHAPXR-elizabeth 910GLIVSTLL-elizabeth
# 910GLIVSTLL-elizabeth 910GFRNDXR-elizabeth
# 910GFRNDXR-elizabeth 910GTOTCTRD-elizabeth
# 910GTOTCTRD-elizabeth 910GBONDST-elizabeth
# 910GBONDST-elizabeth 910GPADTLL-elizabeth
# 910GPADTLL-elizabeth 910GACTONML-elizabeth
# 910GACTONML-elizabeth 910GEALINGB-elizabeth
# 910GEALINGB-elizabeth 910GWEALING-elizabeth
# 910GWEALING-elizabeth 910GHANWELL-elizabeth
# 910GHANWELL-elizabeth 910GSTHALL-elizabeth
# 910GSTHALL-elizabeth 910GHAYESAH-elizabeth
# 910GHAYESAH-elizabeth 910GHTRWAPT-elizabeth
# 910GHTRWAPT-elizabeth 910GHTRWTM4-elizabeth

# %%
#pprint(stops, depth=1, compact=True)
pprint(stops["orderedLineRoutes"][0], depth=2, compact=True)
route_stops = stops["orderedLineRoutes"][0]["naptanIds"]
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.OrderedRoute, '
#           'Tfl.Api.Presentation.Entities',
#  'name': 'Abbey Wood &harr;  Heathrow Terminal 4 ',
#  'naptanIds': ['910GABWDXR', '910GWOLWXR', '910GCSTMHSXR', '910GCANWHRF',
#                '910GWCHAPXR', '910GLIVSTLL', '910GFRNDXR', '910GTOTCTRD',
#                '910GBONDST', '910GPADTLL', '910GACTONML', '910GEALINGB',
#                '910GWEALING', '910GHANWELL', '910GSTHALL', '910GHAYESAH',
#                '910GHTRWAPT', '910GHTRWTM4'],
#  'serviceType': 'Regular'}

# %%
id = "elizabeth"
fromStopPointId = "Whitechapel"
toStopPointId = "910GHTRWTM4"

timetable = fetch_tfl_data(f"/Line/{id}/Timetable/{fromStopPointId}/to/{toStopPointId}")
# Out:
# HTTP Error 400: {"$type":"Tfl.Api.Presentation.Entities.ApiError, Tfl.Api.Presentation.Entities","timestampUtc":"2025-03-21T22:03:08.9493123Z","exceptionType":"ApiArgumentException","httpStatusCode":400,"httpStatus":"BadRequest","relativeUri":"/Line/elizabeth/Timetable/Whitechapel/to/910GHTRWTM4?app_id=Halfway&app_key=21dbb2eeb688456e817278669ba2c9d4","message":"The following stop points are not recognised: Whitechapel"}

# %%
timetable = fetch_tfl_data(f"/Journey/JourneyResults/{fromStopPointId}/to/{toStopPointId}?useRealTimeLiveArrivals=false")
pprint(timetable, depth=2)
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.DisambiguationResult, '
#           'Tfl.Api.Presentation.Entities',
#  'fromLocationDisambiguation': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Disambiguation, '
#                                          'Tfl.Api.Presentation.Entities',
#                                 'disambiguationOptions': [...],
#                                 'matchStatus': 'list'},
#  'journeyVector': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.JourneyVector, '
#                             'Tfl.Api.Presentation.Entities',
#                    'from': 'Whitechapel',
#                    'to': '1000104',
#                    'uri': '/journey/journeyresults/whitechapel/to/910ghtrwtm4?userealtimelivearrivals=false&app_id=halfway&app_key=21dbb2eeb688456e817278669ba2c9d4',
#                    'via': ''},
#  'recommendedMaxAgeMinutes': 1440,
#  'searchCriteria': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.SearchCriteria, '
#                              'Tfl.Api.Presentation.Entities',
#                     'dateTime': '2025-03-21T22:03:00',
#                     'dateTimeType': 'Departing'},
#  'toLocationDisambiguation': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Disambiguation, '
#                                        'Tfl.Api.Presentation.Entities',
#                               'matchStatus': 'identified'},
#  'viaLocationDisambiguation': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Disambiguation, '
#                                         'Tfl.Api.Presentation.Entities',
#                                'matchStatus': 'empty'}}

# %%
id = "elizabeth"
from_ = "910GABWDXR"
to_ = "910GWOLWXR"

for from_, to_ in zip(route_stops, route_stops[1:]):
    timetable = fetch_tfl_data(f"/Journey/JourneyResults/{from_}/to/{to_}?useRealTimeLiveArrivals=false")
    durations = []
    for journey in timetable["journeys"]:
        durations.append(journey["duration"])
    print(f"{from_}->{to_}={min(durations)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       2 from_ = "HUBZWL"
#       3 to_ = "910GWOLWXR"
# ----> 5 for from_, to_ in zip(route_stops, route_stops[1:]):
#       6     timetable = fetch_tfl_data(f"/Journey/JourneyResults/{from_}/to/{to_}?useRealTimeLiveArrivals=false")
#       7     durations = []
#
# NameError: name 'route_stops' is not defined

# %%
id = "elizabeth"
from_ = "910GABWDXR"
to_ = "910GWOLWXR"

for from_, to_ in zip(route_stops, route_stops[1:]):
    timetable = fetch_tfl_data(f"/Journey/JourneyResults/{from_}/to/{to_}?useRealTimeLiveArrivals=false")
    durations = []
    for journey in timetable["journeys"]:
        durations.append(journey["duration"])
    print(f"{from_}->{to_}={min(durations)}")
# Out:
# 910GABWDXR->910GWOLWXR=3
# 910GWOLWXR->910GCSTMHSXR=4
# 910GCSTMHSXR->910GCANWHRF=4
# 910GCANWHRF->910GWCHAPXR=4
# 910GWCHAPXR->910GLIVSTLL=3
# 910GLIVSTLL->910GFRNDXR=2
# 910GFRNDXR->910GTOTCTRD=2
# 910GTOTCTRD->910GBONDST=2
# 910GBONDST->910GPADTLL=4
# 910GPADTLL->910GACTONML=6
# 910GACTONML->910GEALINGB=3
# 910GEALINGB->910GWEALING=2
# 910GWEALING->910GHANWELL=2
# 910GHANWELL->910GSTHALL=3
# 910GSTHALL->910GHAYESAH=3
# 910GHAYESAH->910GHTRWAPT=7
# 910GHTRWAPT->910GHTRWTM4=5

# %%
pprint(timetable, depth=3)
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.ItineraryResult, '
#           'Tfl.Api.Presentation.Entities',
#  'journeyVector': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.JourneyVector, '
#                             'Tfl.Api.Presentation.Entities',
#                    'from': '1001147',
#                    'to': '1000104',
#                    'uri': '/journey/journeyresults/910ghtrwapt/to/910ghtrwtm4?userealtimelivearrivals=false&app_id=halfway&app_key=21dbb2eeb688456e817278669ba2c9d4',
#                    'via': ''},
#  'journeys': [{'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, '
#                         'Tfl.Api.Presentation.Entities',
#                'alternativeRoute': False,
#                'arrivalDateTime': '2025-02-12T15:12:00',
#                'duration': 5,
#                'fare': {...},
#                'legs': [...],
#                'startDateTime': '2025-02-12T15:07:00'},
#               {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, '
#                         'Tfl.Api.Presentation.Entities',
#                'alternativeRoute': False,
#                'arrivalDateTime': '2025-02-12T15:27:00',
#                'duration': 5,
#                'fare': {...},
#                'legs': [...],
#                'startDateTime': '2025-02-12T15:22:00'},
#               {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, '
#                         'Tfl.Api.Presentation.Entities',
#                'alternativeRoute': False,
#                'arrivalDateTime': '2025-02-12T15:39:00',
#                'duration': 12,
#                'fare': {...},
#                'legs': [...],
#                'startDateTime': '2025-02-12T15:27:00'},
#               {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, '
#                         'Tfl.Api.Presentation.Entities',
#                'alternativeRoute': False,
#                'arrivalDateTime': '2025-02-12T15:51:00',
#                'duration': 47,
#                'legs': [...],
#                'startDateTime': '2025-02-12T15:04:00'}],
#  'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Line, '
#                      'Tfl.Api.Presentation.Entities',
#             'created': '2025-02-06T09:58:47.4Z',
#             'crowding': {...},
#             'disruptions': [],
#             'id': 'elizabeth',
#             'lineStatuses': [...],
#             'modeName': 'elizabeth-line',
#             'modified': '2025-02-06T09:58:47.4Z',
#             'name': 'Elizabeth line',
#             'routeSections': [],
#             'serviceTypes': [...]},
#            {'$type': 'Tfl.Api.Presentation.Entities.Line, '
#                      'Tfl.Api.Presentation.Entities',
#             'created': '2025-02-06T09:58:47.4Z',
#             'crowding': {...},
#             'disruptions': [],
#             'id': 'piccadilly',
#             'lineStatuses': [...],
#             'modeName': 'tube',
#             'modified': '2025-02-06T09:58:47.4Z',
#             'name': 'Piccadilly',
#             'routeSections': [],
#             'serviceTypes': [...]}],
#  'recommendedMaxAgeMinutes': 3,
#  'searchCriteria': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.SearchCriteria, '
#                              'Tfl.Api.Presentation.Entities',
#                     'dateTime': '2025-02-12T15:04:00',
#                     'dateTimeType': 'Departing',
#                     'timeAdjustments': {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.TimeAdjustments, '
#                                                  'Tfl.Api.Presentation.Entities',
#                                         'earlier': {...},
#                                         'earliest': {...},
#                                         'later': {...},
#                                         'latest': {...}}},
#  'stopMessages': []}

# %%
pprint(timetable["timetable"]["routes"][0]["schedules"][0]) # periods/frequency
# https://api-portal.tfl.gov.uk/api-details#api=Line&operation=Line_TimetableByPathFromStopPointIdPathId
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pprint(timetable["timetable"]["routes"][0]["schedules"][0]) # periods/frequency
#       2 # https://api-portal.tfl.gov.uk/api-details#api=Line&operation=Line_TimetableByPathFromStopPointIdPathId
#
# KeyError: 'timetable'

# %%
pprint(timetable["timetable"]["routes"][0]["schedules"][0]["periods"][1]["frequency"]["highestFrequency"]) # periods/frequency
pprint(timetable["timetable"]["routes"][0]["schedules"][0]["periods"][1]["frequency"]["lowestFrequency"]) # periods/frequency

# https://api-portal.tfl.gov.uk/api-details#api=Line&operation=Line_TimetableByPathFromStopPointIdPathId

# %%
def time_from_journey(journey):
    return int(journey["hour"]) * 60 + int(journey["minute"])
    
first = timetable["timetable"]["routes"][0]["schedules"][0]["firstJourney"]
first_time = time_from_journey(first)
for schedule in timetable["timetable"]["routes"][0]["schedules"][0]["knownJourneys"][1:]:
    next_time = time_from_journey(schedule)
    print(f"Time between Trains = {next_time - first_time} mins")
    first_time = next_time

# %%
pprint(timetable["timetable"]["routes"][0]["stationIntervals"], depth=2)

# %%
for stop in timetable["timetable"]["routes"][0]["stationIntervals"][0]["intervals"]:
    name = station_id[stop["stopId"]]
    arrivalTime = stop["timeToArrival"]
    print(f"{name}: {arrivalTime}") # Why are there 2 for almost all stations?

# %%
for stop in timetable["timetable"]["routes"][0]["stationIntervals"][1]["intervals"]:
    name = station_id[stop["stopId"]]
    arrivalTime = stop["timeToArrival"]
    print(f"{name}: {arrivalTime}") # Why are there 2 for almost all stations?
