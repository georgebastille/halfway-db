# %%
# !uv pip install pandas orjson
# Out:
# Resolved 7 packages in 368ms
# Prepared 5 packages in 2.01s
# Installed 5 packages in 66ms
#  + numpy==2.3.3
#  + orjson==3.11.3
#  + pandas==2.3.2
#  + pytz==2025.2
#  + tzdata==2025.2

# %%
import pandas as pd
df = pd.read_csv("./Stops.csv")

# I think RLY is station and RSE is station Entrance
df = df.loc[df['StopType'] == some_value]
# Out:
# /tmp/ipykernel_8732/521206972.py:2: DtypeWarning: Columns (1,2,6,8,21,22,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Stops.csv")

# %%
df["StopType"].unique()
# Out:
# array(['BCT', 'RSE', 'FTD', 'BCS', 'TMU', 'AIR', 'BCE', 'TXR', 'STR',
#        'BCQ', 'MET', 'BST', 'RLY', 'RPL', 'GAT', 'FER', 'FBT', 'PLT'],
#       dtype=object)

# %%
pd.set_option('display.max_columns', None)
df.sample(10)
# Out:
#             ATCOCode  NaptanCode PlateCode  CleardownCode  \
# 86059   150007002001    esxagwdt       NaN            NaN
# 391347      61601341  65236849.0       NaN            NaN
# 51474   1000DBBR3379    dbsjadgj       NaN            NaN
# 296193   43000928802    nwmpdjaw       NaN            NaN
# 219956    3300BR0174    ntsawgwa    BR0174            NaN
# 336703    490008924E       58232       NaN            NaN
# 330871    490003959S       56616       NaN            NaN
# 17349   040000003963    bucdtdma       NaN            NaN
# 205930  300000901FZ1         NaN       NaN            NaN
# 341639    490013083N       71292       NaN            NaN
#
#                     CommonName  CommonNameLang ShortCommonName  \
# 86059          Jacksons Corner             NaN             NaN
# 391347  Castlecary House Hotel             NaN             NaN
# 51474             Lumford Mill             NaN             NaN
# 296193                  Oak Rd             NaN             NaN
# ...

# %%
df.loc[df['StopType'] != "BCT"].sample(10)
# Out:
#             ATCOCode NaptanCode PlateCode  CleardownCode  \
# 19655   049005320831    mltatgp       NaN            NaN
# 430866       9300OBA        NaN       NaN            NaN
# 115030   1800SBT0631        NaN       NaN            NaN
# 129233  1900HA100215   hamamwgm       NaN            NaN
# 428961   9100LEYTNMR        NaN       NaN            NaN
# 429606      9100SDON        NaN       NaN            NaN
# 124007  1800ZZMAALT1        NaN       NaN            NaN
# 367043  5520LLHARAN1        NaN       NaN            NaN
# 360838  5330AWB32094    gwetgma       NaN            NaN
# 250162  3800BILBROK0        NaN       NaN            NaN
#
#                                        CommonName  CommonNameLang  \
# 19655                                 Bus Station             NaN
# 430866                        Oban Ferry Terminal             NaN
# 115030              City Centre - Windmill Street             NaN
# 129233                                Bus Station             NaN
# ...
